# %% [markdown]
# R에서 데이터를 읽어들이는 유용한 함수들이 있다.
#
# - `read.table`, `read.csv` : 표 형식의 데이터를 읽음
# - `readLines` : 텍스트 파일을 줄 단위로 읽음
# - `source` : R 코드 파일을 읽음 (`dump`의 반대)
# - `dget` : R 코드 파일을 읽음 (`dput`의 반대)
# - `load` : 저장된 작업공간을 불러들임
# - `unserialize` : 단일 R 오브젝트를 이진 형태로 읽음
#
# R에서 파일로 데이터를 내보내는 함수들은 다음과 같다.
#
# - `write.table`
# - `writeLines`
# - `dump`
# - `dput`
# - `save`
# - `serialize`

# %% [markdown]
# 여기서 가장 중요한 `read.table` 함수를 살펴보자.
#
# ### 1. read.table
#
# read.table은 다음 argument 들을 가지고 있다.
#
# - `file` : 파일의 이름
# - `header` : 불러들일 파일의 헤더가 있는지를 표시
# - `sep` : 열이 어떻게 구분되어있는지 나타내는 문자열
# - `colClasses` : 각 열의 클래스를 나타내는 문자열 벡터
# - `nrows` : 읽어들일 행의 수
# - `comment.char` : 주석 문자열을 나타내는 문자열 (없으면 = "")
# - `skip` : 처음에 생략할 줄의 수
# - `stringsAsFactors` : 문자열 변수를 팩터로 변환할 것인지를 표 (default True)

# %%
data <- readLines("./Materials/UNDHR.txt")
data
# Out:
#   [1] "Universal Declaration of Human Rights "
#   [2] "Preamble "
#   [3] "Whereas recognition of the inherent di"
#   [4] "gnity and of the equal"
#   [5] "and inalienable "
#   [6] "rights of all members of the human fam"
#   [7] "ily is the foundation of freedom, justice "
#   [8] "and peace in the world, "
#   [9] "Whereas disregard and contempt for hum"
#  [10] "an rights have resulted in barbarous "
#  [11] "acts which have outraged the conscience of"
#  [12] "mankind, and the advent of a world "
#  [13] "in which human beings shall enjoy "
#  [14] "freedom of speech and belief and freedom "
#  [15] "from fear and want has "
#  [16] "been proclaimed as the highest aspiration of the common "
#  [17] "people, "
#  [18] "Whereas it is essential, if"
#  [19] "man is not to be compelled "
#  [20] "to have recourse, as a last "
#  [21] "resort, to rebellion against tyranny and "
#  [22] "oppression, that human rights should be "
#  [23] "protected by the rule of law, "
#  [24] "Whereas it is essential to"
#  [25] "promote the development of "
#  [26] "friendly relations between "
#  [27] "nations, "
#  [28] "Whereas the peoples of the United Nations "
#  [29] "have in the Charte"
#  [30] "r reaffirmed their "
#  [31] "faith in fundamental human rights, in t"
#  [32] "he dignity and worth of the human person "
#  [33] "and in the equal rights of men and women and have determined to promote "
#  [34] "social progress and better standards of life in larger freedom, "
#  [35] "Whereas Member States have pledged themselves to achieve, in cooperation "
#  [36] "with the United Nations, the "
#  [37] "promotion of universal respect for and observance of "
#  [38] "human rights and fundamental freedoms, "
#  [39] "Whereas a common understanding of t"
#  [40] "hese rights and freedoms is of the "
#  [41] "greatest importance for the full "
#  [42] "realization of this pledge, "
#  [43] "Now, therefore, "
#  [44] "The General Assembly, "
#  [45] "Proclaims this Universal Declaration "
#  [46] "of Human Rights as a common standard of "
#  [47] "achievement for all peoples and all nations"
#  [48] ", to the end that every individual and "
#  [49] "every organ of society, keeping this Declarat"
#  [50] "ion constantly in mind, shall strive by "
#  [51] "teaching and education to promote res"
#  [52] "pect for these rights and freedoms and by "
#  [53] "progressive measures, national and internat"
#  [54] "ional, to secure their universal and "
#  [55] "effective recognition and observance, bot"
#  [56] "h among the peoples of Member States "
#  [57] "themselves and among the peoples of terr"
#  [58] "itories under their jurisdiction. "
#  [59] "Article I "
#  [60] "All human beings are born free and equal in dignity and rights. They are "
#  [61] "endowed with reason and conscience and should act towards one another in a "
#  [62] "spirit of brotherhood. "
#  [63] "Article 2 "
#  [64] "Everyone is entitled to all the rights and fr"
#  [65] "eedoms set forth in this Declaration, "
#  [66] "without distinction of any kind, such as"
#  [67] "race, colour, sex, language, religion, "
#  [68] "political or other opinion, national or social origin, propert"
#  [69] "y, birth or other status. "
#  [70] "Furthermore, no distinction shall be "
#  [71] "made on the basis of the political, "
#  [72] "jurisdictional or international status of "
#  [73] "the country or territory to which a person "
#  [74] "belongs, whether it be independent, trust, non-self-gov"
#  [75] "erning or under any other "
#  [76] "limitation of sovereignty. "
#  [77] "Article 3 "
#  [78] "Everyone has the right to life, liberty and security of person. "
#  [79] "Article 4 "
#  [80] "No one shall be held in slav"
#  [81] "ery or servitude; slavery "
#  [82] "and the slave trade shall be "
#  [83] "prohibited in all their forms. "
#  [84] "Article 5 "
#  [85] "No one shall be subjected to "
#  [86] "torture or to cruel, inhu"
#  [87] "man or degrading treatment "
#  [88] "or punishment. "
#  [89] "Article 6 "
#  [90] "Everyone has the right to recognition ev"
#  [91] "erywhere as a person before the law. "
#  [92] "Article 7 "
#  [93] "All are equal before the la"
#  [94] "w and are entitled without any "
#  [95] "discrimination to equal "
#  [96] "protection of the law. "
#  [97] "All are entitled to equal protection against any "
#  [98] "discrimination in violation of this Decl"
#  [99] "aration and against any incitement to such "
# [100] "discrimination. "
# [101] "Article 8 "
# [102] "Everyone has the right to an effective rem"
# [103] "edy by the competent national tribunals "
# [104] "for acts violating the fundament"
# [105] "al rights granted him by the constitution or by law. "
# [106] "Article 9 "
# [107] "No one shall be subjected to arbitr"
# [108] "ary arrest, detention or exile. "
# [109] "Article 10 "
# [110] "Everyone is entitled in full equality to a fair and public "
# [111] "hearing by an independent "
# [112] "and impartial tribunal, in the determination "
# [113] "of his rights and obligations and of any "
# [114] "criminal charge against him. "
# [115] "Article 11 "
# [116] "1. Everyone charged with a penal off"
# [117] "ence has the right to be presumed "
# [118] "innocent until proved guilty according to"
# [119] "law in a public trial at which he "
# [120] "has had all the guarantees necessary for his defence. "
# [121] "2. No one shall be held guilty of any penal"
# [122] "offence on account of any act or "
# [123] "omission which did not constitute "
# [124] "a penal offence, under national or "
# [125] "international law, at the time when it was committed. Nor shall a heavier "
# [126] "penalty be imposed than the one that was applicable at the time the penal "
# [127] "offence was committed. "
# [128] "Article 12 "
# [129] "No one shall be subjected to arbitrary in"
# [130] "terference with his privacy, family, home "
# [131] "or correspondence, nor to"
# [132] "attacks upon his honour and reputation. Everyone has "
# [133] "the right to the protecti"
# [134] "on of the law against such interference or attacks. "
# [135] "Article 13 "
# [136] "1. Everyone has the right to freedom "
# [137] "of movement and residence within the "
# [138] "borders of each State. "
# [139] "2. Everyone has the right to leave any country, including his own, and to "
# [140] "return to his country. "
# [141] "Article 14 "
# [142] "1. Everyone has the right to seek and to"
# [143] "enjoy in other countries asylum from "
# [144] "persecution. "
# [145] "2. This right may not be invoked in"
# [146] "the case of prosecutions genuinely "
# [147] "arising from non-political crimes or fr"
# [148] "om acts contrary to the purposes and "
# [149] "principles of the United Nations. "
# [150] "Article 15 "
# [151] "1. Everyone has the right to a nationality. "
# [152] "2. No one shall be arbitrarily deprived of"
# [153] "his nationality nor denied the right to "
# [154] "change his nationality. "
# [155] "Article 16 "
# [156] "1. Men and women of full age, without "
# [157] "any limitation due to race, nationality "
# [158] "or religion, have the right to marry "
# [159] "and to found a family. They are entitled "
# [160] "to equal rights as to marriage, dur"
# [161] "ing marriage and at its dissolution. "
# [162] "2. Marriage shall be entered into only wit"
# [163] "h the free and full consent of the "
# [164] "intending spouses. "
# [165] "3. The family is the natural and fund"
# [166] "amental group unit of society and is "
# [167] "entitled to protection by society and the State. "
# [168] "Article 17 "
# [169] "1. Everyone has the right to own property"
# [170] "alone as well as in association with "
# [171] "others. "
# [172] "2. No one shall be arbitrarily deprived of his property. "
# [173] "Article 18 "
# [174] "Everyone has the right to freedom of t"
# [175] "hought, conscience and religion; this right "
# [176] "includes freedom to change his religion or belief, and freedom, either alone or in "
# [177] "community with others and in publi"
# [178] "c or private, to manifest"
# [179] "his religion or belief in "
# [180] "teaching, practice, worship and observance. "
# [181] "Article 19 "
# [182] "Everyone has the right to freedom of opini"
# [183] "on and expression; this right includes "
# [184] "freedom to hold opinions wit"
# [185] "hout interference and to seek, receive and impart "
# [186] "information and ideas through any medi"
# [187] "a and regardless of frontiers. "
# [188] "Article 20 "
# [189] "1. Everyone has the right to freedom of"
# [190] "peaceful assembly and association. "
# [191] "2. No one may be compelled to belong to an association. "
# [192] "Article 21 "
# [193] "1. Everyone has the right to take par"
# [194] "t in the government of his country, "
# [195] "directly or through freely chosen representatives. "
# [196] "2. Everyone has the right to equal access "
# [197] "to public service in his country. "
# [198] "3. The will of the people shall be the "
# [199] "basis of the authority of government; "
# [200] "this will shall be expressed in periodic and genuine elections which shall "
# [201] "be by universal and equal suffrage and sha"
# [202] "ll be held by secret vote or by "
# [203] "equivalent free voting procedures. "
# [204] "Article 22 "
# [205] "Everyone, as a member of society, has t"
# [206] "he right to social security and is entitled "
# [207] "to realization, through nat"
# [208] "ional effort and international co-operation and in "
# [209] "accordance with the organization and resour"
# [210] "ces of each State, of the economic, "
# [211] "social and cultural rights indispensable for his dignity and the free development "
# [212] "of his personality. "
# [213] "Article 23 "
# [214] "1. Everyone has the right to work, to fr"
# [215] "ee choice of employment, to just and "
# [216] "favourable conditions of work and to"
# [217] "protection against unemployment. "
# [218] "2. Everyone, without any discrimination,"
# [219] "has the right to equal pay for equal "
# [220] "work. "
# [221] "3. Everyone who works has the right to just and favourable remuneration "
# [222] "ensuring for himself and his family an existence worthy of human dignity, "
# [223] "and supplemented, if necessary, by other"
# [224] "means of social protection. "
# [225] "4. Everyone has the right to form and to join trade unions for the protection of "
# [226] "his interests. "
# [227] "Article 24 "
# [228] "Everyone has the right to rest and leis"
# [229] "ure, including reas"
# [230] "onable limitation of "
# [231] "working hours and periodic holidays with pay. "
# [232] "Article 25 "
# [233] "1. Everyone has the right to a st"
# [234] "andard of living adequate for the health and "
# [235] "well-being of himself and of his fam"
# [236] "ily, including food, clothing, housing "
# [237] "and medical care and necessary social "
# [238] "services, and the right to security "
# [239] "in the event of unemployment, sickne"
# [240] "ss, disability, widowhood, old age or "
# [241] "other lack of livelihood in circ"
# [242] "umstances beyond his control. "
# [243] "2. Motherhood and childhood are "
# [244] "entitled to special care and assistance. All "
# [245] "children, whether born in or out of w"
# [246] "edlock, shall enjoy the same social "
# [247] "protection. "
# [248] "Article 26 "
# [249] "1. Everyone has the right to education. E"
# [250] "ducation shall be free, at least in the "
# [251] "elementary and fundamental stages. "
# [252] "Elementary education shall be "
# [253] "compulsory. Technical and prof"
# [254] "essional education shall be made "
# [255] "generally available and higher education shall be equa"
# [256] "lly accessible to all "
# [257] "on the basis of merit. "
# [258] "2. Education shall be directed to "
# [259] "the full development of the human "
# [260] "personality and to the strengthening of respect for human rights and "
# [261] "fundamental freedoms. It shall promote understanding, tolerance and "
# [262] "friendship among all nations, racial or"
# [263] "religious groups, and shall further "
# [264] "the activities of the United Nati"
# [265] "ons for the maintenance of peace. "
# [266] "3. Parents have a prior right to choos"
# [267] "e the kind of education that shall be "
# [268] "given to their children. "
# [269] "Article 27 "
# [270] "1. Everyone has the right freely to part"
# [271] "icipate in the cultural life of the "
# [272] "community, to enjoy the arts and to share in scientific advancement and "
# [273] "its benefits. "
# [274] "2.  Everyone has the right to the protec"
# [275] "tion of the moral and material interests "
# [276] "resulting from any scientific, literary or "
# [277] "artistic production of which he is the "
# [278] "author.  "
# [279] "Article 28  "
# [280] "Everyone is entitled to a social and in"
# [281] "ternational order in"
# [282] " which the rights and "
# [283] "freedoms set forth in this Declar"
# [284] "ation can be fully realized.  "
# [285] "Article 29  "
# [286] "1.  Everyone has duties to the community in which alone the free and full "
# [287] "development of his personality is possible.  "
# [288] "2.  In the exercise of his rights and "
# [289] "freedoms, everyone shall be subject only "
# [290] "to such limitations as are determin"
# [291] "ed by law solely for the purpose of "
# [292] "securing due recognition and respect "
# [293] "for the rights and "
# [294] "freedoms of others "
# [295] "and of meeting the just requirement"
# [296] "s of morality, public order and the "
# [297] "general welfare in a democratic society.  "
# [298] "3.  These rights and freedoms may in no ca"
# [299] "se be exercised contrary to the "
# [300] "purposes and principles "
# [301] "of the United Nations.  "
# [302] "Article 30  "
# [303] "Nothing in this Declaration may be interpre"
# [304] "ted as implying for any"
# [305] " State, group or "
# [306] "person any right to engage in any activity"
# [307] " or to perform any act aimed at the "
# [308] "destruction of any of the right"
# [309] "s and freedoms set forth herein.  "

# %% [markdown]
# ### 2. read.table로 훨씬 큰 데이터셋 불러오기
#
# 사실 `colClasses` 파라미터를 활용하는 것이 매우 중요하다. 이 옵션을 사용하면 `read.table` 함수를 훨씬 빠르게 (거의 두 배 가까이) 만들 수 있다.
#
# 만약 모든 열이 "numeric"이면, colClass = "numeric"으로 둔다.

# %%
# 각 열의 클래스를 찾는 빠른 방법 ( Quick & Dirty way )
initial <- read.table("datatable.txt", nrows = 100)
classes <- sapply(initial, class)
tabAll <- read.table("datatable.txt", colClasses = classes)
# Out:
# Warning message in file(file, "rt"):
# “파일 'datatable.txt'를 여는데 실패했습니다: 그런 파일이나 디렉터리가 없습니다”
# Error in file(file, "rt"): 커넥션을 열 수 없습니다
# Traceback:
#
# 1. read.table("datatable.txt", nrows = 100)
# 2. file(file, "rt")

# %% [markdown]
# 또한, 시스템에 관해 잘 알고 있는 것이 중요하다.
#
# - 가용한 메모리가 어느 정도인가?
# - 다른 프로그램을 사용하고 있는가?
# - 같은 시스템에 접속한 다른 사용자가 있는가?
# - 운영체제가 어떤 것인가?
# - OS가 32비트? 64비트?
#
#
# 다음과 같이 러프하게 메모리 필요량을 계산할 수 있다.
#
# 만약 1,500,000개의 행과, 120개의 열로 구성된 데이터프레임이 있고, 모든 데이터가 수치형 데이터라면, 대략 메모리가 얼마나 필요할까?
#
# 1,500,000 \* 120 \* 8bytes/numeric
# <br>= 14400000000 bytes
# <br>= 14400000000 / 2^20 bytes/MB
# <br>= 1,373.29 MB
# <br>= 1.34GB
#
# 하지만 이보다는 더 필요할 것이다. (대략 2배라고 생각하면 2.6GB 정도)

# %% [markdown]
# ### Textual Formats
#
# `dumping` 과 `dput`의 결과물은 편집 가능하고, 복구 할 수 있기 때문에 유용하다.
#
# table이나 csv파일과 달리, `dump`와 `dput`은 메타데이터를 보존한다.
#
# 텍스트 포맷은 버전 컨트롤이 가능한 프로그램에서 훨씬 더 효율적이다.

# %%
y <- data.frame(a = 1, b = "a")
dput(y)
# Out:
# structure(list(a = 1, b = structure(1L, .Label = "a", class = "factor")), .Names = c("a",
# "b"), row.names = c(NA, -1L), class = "data.frame")

# %%
# dput은 모든 메타데이터를 보존한다 (단일 오브젝트의)
dput(y, file= "./Materials/y.R")
new.y <- dget("./Materials/y.R")
new.y
# Out:
#   a b
# 1 1 a

# %%
# dput과 달리 dump는 여러 오브젝트의 메타데이터를 보존한다
x <- "foo"
y <- data.frame(a = 1, b = "a")
dump(c("x", "y"), file = "./Materials/data.R")
rm(x, y)  # x, y 제거
source("./Materials/data.R")  # dump의 반대 명령어. 데이터를 불러온다.
y
x
# Out:
#   a b
# 1 1 a
# [1] "foo"

# %% [markdown]
# ### 외부 파일과의 연결
#
# - `file` : 특정 파일에 연결한다
# - `gzfile` : gzip으로 압축된 파일에 연결한다
# - `bzfile` : bzip2로 압축된 파일에 연결한다
# - `url` : 특정 웹페이지에 연결한다

# %%
str(file)
# Out:
# function (description = "", open = "", blocking = TRUE, encoding = getOption("encoding"),
#     raw = FALSE, method = getOption("url.method", "default"))

# %%
# Using File & read.csv
con <- file("./Materials/UNDHR.txt", "r")
data <- read.csv(con)
close(con)

# is the same as
data <- read.csv("./Materials/UNDHR.txt")

# %%
# Reading Lines of a Text File
# 10줄을 읽어온다
con <- gzfile("words.gz")
x <- readLines(con, 10)
x
# Out:
# Warning message in readLines(con, 10):
# “압축된 파일 'words.gz'를 열 수 없습니다.  그 이유는 아마도 '그런 파일이나 디렉터리가 없습니다'입니다”
# Error in readLines(con, 10): 커넥션을 열 수 없습니다
# Traceback:
#
# 1. readLines(con, 10)

# %%
# Reading from URL

con <- url("http://www.google.com", "r")
x <- readLines(con, 10)
head(x)
# Out:
# Warning message in readLines(con, 10):
# “'http://www.google.com'에서 불완전한 마지막 행이 발견되었습니다”
# [1] "<!doctype html><html itemscope=\"\" itemtype=\"http://schema.org/WebPage\" lang=\"ko\"><head><meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"><meta content=\"/images/branding/googleg/1x/googleg_standard_color_128dp.png\" itemprop=\"image\"><title>Google</title><script nonce=\"vsOVAF//nyctBngWl08KcQ==\">(function(){window.google={kEI:'p0uaWqbeNIyY8wXd8KTgCg',kEXPI:'1353809,1354187,1354277,1354916,1355174,1355675,1355762,1356040,1356180,1356779,1356854,1357034,1357219,1357452,1357717,3700268,3700521,4029815,4031109,4043492,4045841,4048347,4081039,4097147,4097470,4097922,4097929,4098721,4098728,4104658,4109316,4109490,4116279,4116731,4116926,4116935,4118798,4120660,4122511,4124850,4125837,4126203,4127086,4127418,4128586,4129001,4129520,4129633,4130362,4130783,4131247,4131834,4133403,4133755,4135025,4135045,4136073,4136105,4136379,4137461,4137597,4137646,4141832,4142071,4142328,4142834,4143278,4143677,4144233,4144442,4144545,4144803,4145088,4145108,4145461,4145485,4145772,4145836,4146146,4146873,4147900,4147943,4148268,4148280,4148314,4148399,4148497,4148571,4148608,4148928,4149017,4149271,4149304,4149337,4149372,4150005,4150017,4150429,4151052,4151295,4151406,4151766,4153062,4153222,4153545,4153605,4153952,4154017,4154042,4154081,4154189,4154243,4154375,4154506,4154872,4155119,4155567,4155569,4155684,4156009,4156181,4156331,4156634,4156657,4156663,4156697,4157382,4157890,4158061,4158208,10200083,10202524,19000288,19000423,19000427,19001999,19002548,19002880,19003321,19003323,19003325,19003326,19003328,19003329,19003330,19003407,19003408,19003409,19004309,19004516,19004517,19004518,19004519,19004520,19004521,19004892,19004896,19005036,19005038,19005108,19005112,19005123',authuser:0,kscs:'c9c918f0_p0uaWqbeNIyY8wXd8KTgCg',u:'c9c918f0',kGL:'KR'};google.kHL='ko';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute(\"eid\")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute(\"leid\")));)a=a.parentNode;return b};google.https=function(){return\"https:\"==window.location.protocol};google.ml=function(){return null};google.wl=function(a,b){try{google.ml(Error(a),!1,b)}catch(d){}};google.time=function(){return(new Date).getTime()};google.log=function(a,b,d,c,g){if(a=google.logUrl(a,b,d,c,g)){b=new Image;var e=google.lc,f=google.li;e[f]=b;b.onerror=b.onload=b.onabort=function(){delete e[f]};google.vel&&google.vel.lu&&google.vel.lu(a);b.src=a;google.li=f+1}};google.logUrl=function(a,b,d,c,g){var e=\"\",f=google.ls||\"\";d||-1!=b.search(\"&ei=\")||(e=\"&ei=\"+google.getEI(c),-1==b.search(\"&lei=\")&&(c=google.getLEI(c))&&(e+=\"&lei=\"+c));c=\"\";!d&&google.cshid&&-1==b.search(\"&cshid=\")&&(c=\"&cshid=\"+google.cshid);a=d||\"/\"+(g||\"gen_204\")+\"?atyp=i&ct=\"+a+\"&cad=\"+b+e+f+\"&zx=\"+google.time()+c;/^http:/i.test(a)&&google.https()&&(google.ml(Error(\"a\"),!1,{src:a,glmm:1}),a=\"\");return a};}).call(this);(function(){google.y={};google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};}).call(this);google.f={};var a=window.location,b=a.href.indexOf(\"#\");if(0<=b){var c=a.href.substring(b+1);/(^|&)q=/.test(c)&&-1==c.indexOf(\"#\")&&a.replace(\"/search?\"+c.replace(/(^|&)fp=[^&]*/g,\"\")+\"&cad=h\")};</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important} ...
# [2] "</style><style>body,td,a,p,.h{font-family:\xb1\xbc\xb8\xb2,\xb5\xb8\xbf\xf2,arial,sans-serif}.ko{font-size:9pt}body{margin:0;overflow-y:scroll}#gog{padding:3px 8px 0}td{line-height:.8em}.gac_m td{line-height:17px}form{margin-bottom:20px}.h{color:#36c}.q{color:#00c}.ts td{padding:0}.ts{border-collapse:collapse}em{font-weight:bold;font-style:normal}.lst{height:25px;width:496px}.gsfi,.lst{font:18px arial,sans-serif}.gsfs{font:17px arial,sans-serif}.ds{display:inline-box;display:inline-block;margin:3px 0 4px;margin-left:4px}input{font-family:inherit}a.gb1,a.gb2,a.gb3,a.gb4{color:#11c !important}body{background:#fff;color:black}a{color:#11c;text-decoration:none}a:hover,a:active{text-decoration:underline}.fl a{color:#36c}a:visited{color:#551a8b}a.gb1,a.gb4{text-decoration:underline}a.gb3:hover{text-decoration:none}#ghead a.gb2:hover{color:#fff !important}.sblc{padding-top:5px}.sblc a{display:block;margin:2px 0;margin-left:13px;font-size:11px}.lsbb{background:#eee;border:solid 1px;border-color:#ccc #999 #999 #ccc;height:30px}.lsbb{display:block}.ftl,#fll a{display:inline-block;margin:0 12px}.lsb{background:url(/images/nav_logo229.png) 0 -261px repeat-x;border:none;color:#000;cursor:pointer;height:30px;margin:0;outline:0;font:15px arial,sans-serif;vertical-align:top}.lsb:active{background:#ccc}.lst:focus{outline:none}.tiah{width:458px}</style><script nonce=\"vsOVAF//nyctBngWl08KcQ==\"></script><link href=\"/images/branding/product/ico/googleg_lodp.ico\" rel=\"shortcut icon\"></head><body bgcolor=\"#fff\"><script nonce=\"vsOVAF//nyctBngWl08KcQ==\">(function(){var src='/images/nav_logo229.png';var iesg=false;document.body.onload = function(){window.n && window.n();if (document.images){new Image().src=src;}"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# [3] "if (!iesg){document.f&&document.f.q.focus();document.gbqf&&document.gbqf.q.focus();}"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# [4] "}"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# [5] "})();</script><div id=\"mngb\"> <div id=gbar><nobr><b class=gb1>\xb0˻\xf6</b> <a class=gb1 href=\"http://www.google.co.kr/imghp?hl=ko&tab=wi\">\xc0̹\xcc\xc1\xf6</a> <a class=gb1 href=\"http://maps.google.co.kr/maps?hl=ko&tab=wl\">\xc1\xf6\xb5\xb5</a> <a class=gb1 href=\"https://play.google.com/?hl=ko&tab=w8\">Play</a> <a class=gb1 href=\"http://www.youtube.com/?gl=KR&tab=w1\">YouTube</a> <a class=gb1 href=\"http://news.google.co.kr/nwshp?hl=ko&tab=wn\">\xb4\xba\xbd\xba</a> <a class=gb1 href=\"https://mail.google.com/mail/?tab=wm\">Gmail</a> <a class=gb1 href=\"https://drive.google.com/?tab=wo\">\xb5\xe5\xb6\xf3\xc0̺\xea</a> <a class=gb1 style=\"text-decoration:none\" href=\"https://www.google.co.kr/intl/ko/options/\"><u>\xb4\U0017ae31\xe2</u> &raquo;</a></nobr></div><div id=guser width=100%><nobr><span id=gbn class=gbi></span><span id=gbf class=gbf></span><span id=gbe></span><a href=\"http://www.google.co.kr/history/optout?hl=ko\" class=gb4>\xc0\xa5 \xb1\xe2\xb7\xcf</a> | <a  href=\"/preferences?hl=ko\" class=gb4>\xbc\xb3\xc1\xa4</a> | <a target=_top id=gb_70 href=\"https://accounts.google.com/ServiceLogin?hl=ko&passive=true&continue=http://www.google.co.kr/%3Fgfe_rd%3Dcr%26dcr%3D0%26ei%3Dp0uaWpXsJtSQ9QXQk4PwCA\" class=gb4>\xb7α\xd7\xc0\xce</a></nobr></div><div class=gbh style=left:0></div><div class=gbh style=right:0></div> </div><center><br clear=\"all\" id=\"lgpd\"><div id=\"lga\"><div style=\"padding:28px 0 3px\"><div style=\"height:110px;width:276px;background:url(/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png) no-repeat\" title=\"Google\" align=\"left\" id=\"hplogo\" onload=\"window.lol&&lol()\"><div style=\"color:#777;font-size:16px;font-weight:bold;position:relative;top:70px;left:218px\" nowrap=\"\">\xc7ѱ\xb9"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# [6] "</div></div></div><br></div><form action=\"/search\" name=\"f\"><table cellpadding=\"0\" cellspacing=\"0\"><tr valign=\"top\"><td width=\"25%\">&nbsp;</td><td align=\"center\" nowrap=\"\"><input name=\"ie\" value=\"EUC-KR\" type=\"hidden\"><input value=\"ko\" name=\"hl\" type=\"hidden\"><input name=\"source\" type=\"hidden\" value=\"hp\"><input name=\"biw\" type=\"hidden\"><input name=\"bih\" type=\"hidden\"><div class=\"ds\" style=\"height:32px;margin:4px 0\"><div style=\"position:relative;zoom:1\"><input style=\"color:#000;margin:0;padding:5px 8px 0 6px;vertical-align:top;padding-right:38px\" autocomplete=\"off\" class=\"lst tiah\" value=\"\" title=\"Google \xb0˻\xf6\" maxlength=\"2048\" name=\"q\" size=\"57\"><img src=\"/textinputassistant/tia.png\" style=\"position:absolute;cursor:pointer;right:5px;top:4px;z-index:300\" onclick=\"(function(){var src='/textinputassistant/11/ko_tia.js';var s=document.createElement('script');s.src=src;(document.getElementById('xjsc')||document.body).appendChild(s);})();\" alt=\"\" height=\"23\" width=\"27\"></div></div><br style=\"line-height:0\"><span class=\"ds\"><span class=\"lsbb\"><input class=\"lsb\" value=\"Google \xb0˻\xf6\" name=\"btnG\" type=\"submit\"></span></span><span class=\"ds\"><span class=\"lsbb\"><input class=\"lsb\" value=\"I\xa1\xafm Feeling Lucky\" name=\"btnI\" onclick=\"if(this.form.q.value)this.checked=1; else top.location='/doodles/'\" type=\"submit\"></span></span></td><td class=\"fl sblc\" align=\"left\" nowrap=\"\" width=\"25%\"><a href=\"/advanced_search?hl=ko&amp;authuser=0\">\xb0\xed\xb1ް˻\xf6</a><a href=\"/language_tools?hl=ko&amp;authuser=0\">\xbe\xf0\xbe\xb1\xb8</a></td></tr></table><input id=\"gbv\" name=\"gbv\" type=\"hidden\" value=\"1\"></form><div id=\"gac_scont\"></div><div style=\"font-size:83%;min-height:3.5em\"><br></div><span id=\"footer\"><div style=\"font-size:10pt\"><div style=\"margin:19px auto;text-align:center\" id=\"fll\"><a href=\"/intl/ko/ads/\">\xb1\xa4\xb0\xed \xc7\xc1\xb7α\u05f7\xa5</a><a href=\"http://www.google.co.kr/intl/ko/services/\">\xba\xf1\xc1\xee\xb4Ͻ\xba \xbcַ\xe7\xbc\xc7</a><a href=\"https://plus.google.com/102197601262446632410\" rel=\"publisher\">+Google</a><a href=\"/intl/ko/about.html\">Google \xc1\xa4\xba\xb8</a><a href=\"http://www.google.co.kr/setprefdomain?prefdom=US&amp;sig=__yZhu8I6GXJqAs0I8dwz3JLYC978%3D\" id=\"fehl\">Google.com</a></div></div><p style=\"color:#767676;font-size:8pt\">&copy; 2018 - <a href=\"/intl/ko/policies/privacy/\">\xb0\xb3\xc0\xce\xc1\xa4\xba\xb8ó\xb8\xae\xb9\xe6ħ</a> - <a href=\"/intl/ko/policies/terms/\">\xbe\xe0\xb0\xfc</a></p></span></center><script nonce=\"vsOVAF//nyctBngWl08KcQ==\">(function(){window.google.cdo={height:0,width:0};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d=\"CSS1Compat\"==c.compatMode?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}a&&b&&(a!=google.cdo.width||b!=google.cdo.height)&&google.log(\"\",\"\",\"/client_204?&atyp=i&biw=\"+a+\"&bih=\"+b+\"&ei=\"+google.kEI);}).call(this);})();</script><div id=\"xjsd\"></div><div id=\"xjsi\"><script nonce=\"vsOVAF//nyctBngWl08KcQ==\">(function(){function c(b){window.setTimeout(function(){var a=document.createElement(\"script\");a.src=b;google.timers&&google.timers.load.t&&google.tick(\"load\",{gen204:\"xjsls\",clearcut:31});document.getElementById(\"xjsd\").appendChild(a)},0)}google.dljp=function(b,a){google.xjsu=b;c(a)};google.dlj=c;}).call(this);if(!google.xjs){window._=window._||{};window._DumpException=window._._DumpException=function(e){throw e};google.dljp('/xjs/_/js/k\\x3dxjs.hp.en.QrXCVgTrTTI.O/m\\x3dsb_he,d/am\\x3dKEA/rt\\x3dj/d\\x3d1/t\\x3dzcms/rs\\x3dACT90oGG0LsXeXSwQYUuLtT5ws2-1Mntkw','/xjs/_/js/k\\x3dxjs.hp.en.QrXCVgTrTTI.O/m\\x3dsb_he,d/am\\x3dKEA/rt\\x3dj/d\\x3d1/t\\x3dzcms/rs\\x3dACT90oGG0LsXeXSwQYUuLtT5ws2-1Mntkw');google.xjs=1;}google.pmc={\"sb_he\":{\"agen\":true,\"cgen\":true,\"client\":\"heirloom-hp\",\"dh\":true,\"dhqt\":true,\"ds\":\"\",\"fl\":t ...

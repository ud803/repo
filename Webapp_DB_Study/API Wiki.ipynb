# %% [markdown]
# # API
# https://zapier.com/learn/apis/
#
# ### 정의
# 이전까지, 데이터의 사용은 일반 사람들에 의해 이루어졌다. 텍스트 편집기, 이미지 편집기 등 여러 소프트웨어들은 '인간'이라는 사용자를 바탕으로 만들어졌고, 그에 따라 **UI(User Interface)**- 소프트웨어의 소비를 가능한 쉽고 재밌게 만드는 행위-가 중요시되었다.
#
# 하지만 동일한 데이터, 기능을 제공하되, 이것들을 인간이 아닌 다른 소프트웨어에 제공한다면 어떻게 될까?
#
# 이런 경우에, UI가 신경써야 할 것은 매우 달라진다. 소프트웨어는 눈도 없고, 감정도, 직관도 없다. 따라서 User Interface가 인간에게 주목했던 것과 마찬가지로, 새로운 사용자인 Software에 주목할 필요가 생겨났다.
#
# 바로 **API**의 탄생이다.
#
# API는 UI와 아주 비슷하지만, 사람 대신 소프트웨어를 그 사용자로 가정한다는 것이 차별점이다. 따라서 미디어에서 'API'를 어플리케이션끼리 대화하는 수단으로서 설명하는 이유를 이해할 수 있다. 또한 API는 'Machine-readable Interface'라고도 불린다.(vs. Human-readable)
#
#
# API(Application Programming Interface)란 소프트웨어 어플리케이션에 접근할 수 있는 접근 권한을 주는 것이다.
#
# API는 고객들에게 열려있을 수 있고, 제한된 내부 직원들에게만 공개될 수도 있다.
# Application/Client -> API Request -> Server/DataSource -> API Response
#
# ![title](./images/API.PNG)
#
#
# ### 원리
# 두 개의 시스템(웹사이트, 데스크탑, 스마트폰)이 API를 통해 연결될 때, 우리는 그들이 "**integrated**" 되었다고 말한다.
#
# 이러한 연결에서, 한 쪽은 API를 공급하는 'Server(서버)'이고, 다른 쪽은 'Client(클라이언트/사용자)'이다.
#
# 이 둘 간에 데이터가 오고가기 위해서는 사전에 정해진 'Protocol(규약)'을 거쳐야 한다.
# 서버가 사용자의 메시지가 어떠한 형태로 올 지 사전에 안다면, 훨씬 더 효율적으로 대화할 수 있기 때문이다.
#
# 웹에서, 메인 프로토콜은 **HTTP(Hyper-Text Transfer Protocol)**이다. HTTP의 범용성 때문에, 많은 기업들은 API의 프로토콜로 그대로 사용한다.
#
# 기존의 것을 사용하기 때문에 개발자들의 러닝 커브를 낮춰주고, API에 효율적인 HTTP의 기능들이 꽤 있다. (나중에 설명)
#
# ##### 1. HTTP Request
# HTTP에서의 통신은 **Request-Response** 사이클을 통해 이루어진다.
# 클라이언트가 어떤 요청을 보내면, 서버는 응답을 해주는 방식이다.
#
# <br><br>
# ![title](./images/RRCycle.PNG)
#
# 유효한 요청을 만들려면, 클라이언트는 다음 네 가지를 포함해야 한다.
# - URL(Uniform Resource Locator)
#     - URL은 개개인에 주어진 고유한 주소이다
#     - 어떤 '것'들이 주소를 받는가는 서버를 운영하는 개발자에게 달려있다
#     - URL은 웹페이지, 이미지, 혹은 비디오에도 생성될 수 있다.
#     - API는 여기서 더 나아가 '고객', '제품', 'Tweet' 등에 URL을 포함하고 있다
#     - 따라서 URL은 클라이언트가 서버에게 원하는 바를 명확히 말할 수 있게 되었다
#     - 물론 API는 그들을 "Thing"이라 부르지 않고 "Resource"라고 부른다.
# - Method
#     - 요청의 메서드는 클라이언트가 원하는 작업이 어떤 종류의 것인지를 말해준다
#     - 메서드는 'Request verb'로도 부른다
#     - 자주 쓰이는 메서드는 다음과 같다
#         - GET - 리소스를 가져오도록 서버에 요청한다
#         - POST - 새로운 리소스를 만들도록 서버에 요청한다
#         - PUT - 기존의 리소스를 편집/업데이트하도록 서버에 요청한다
#         - DELETE - 리소스를 제거하도록 서버에 요청한다
# - List of Headers
#     - 헤더는 요청에 대한 메타데이터를 제공한다
#     - 요청을 보낸 시간이나 요청의 사이즈 등의 간단한 리스트이다
#     - 모바일 환경에서 작동하는 홈페이지를 방문한 경험이 있을 것이다.
#     - 이는 HTTP 헤더 중 "**User-Agent**"라는 녀석에 의해 가능한데, 클라이언트는 이를 서버에 보내 어떤 기기를 사용중인지 말해준다.
# - Body
#     - 요청의 바디는 클라이언트가 서버에 보내고자 하는 데이터를 포함한다
#     - 바디의 독특한 특징은 클라이언트가 이 부분에 대해 완전한 통제를 한다는 점이다
#     - HTTP 프로토콜이 정해진 규격을 요구하는 메서드, URL, 헤더와 달리, 바디는 클라이언트가 어떤 것이든 보내도록 해준다
#
# ![title](./images/Request.PNG)
#
#
# ##### 2. HTTP Response
# 서버가 요청(Request)을 받은 후에, 클라이언트에 다시 응답(Response)을 보낸다.
#
# 이 응답은 요청과 구조가 매우 유사한데, '메서드'와 'URL' 대신 'status code'를 포함한다는 점이다.
#
# - Status Code
#     - 상태 코드는 3자리로 구성되어있고, 각각 고유한 의미를 가지고 있다
#     - API에서 제대로 쓰일 경우, 클라이언트에게 많은 정보를 전달해줄 수 있다
#     - 예를 들어, 대표적인 404는 "Not Found" 코드이다 (200 : succes! / 503 : APi currently down)
#
# 응답이 클라이언트에게 보내지면, Request-Response 사이클은 끝이 난다.
#
# ![title](./images/Response.PNG)
#
#
# ### 데이터 타입
# 사람들과 데이터를 공유할 때, 정보를 어떻게 보여줄 것인가는 인간에게 달려있다.
#
# "A well-designed format is dictated by what makes the information the easiest for the intended audience to understand."
#
# 컴퓨터에는 정해진 포맷이 있으며, API에서 가장 많이 쓰이는 포맷은 **JSON, XML, CSV**이다.
#
# ##### 1. JSON(JavaScript Object Notation)
# JSON은 자바스크립트 언어를 기반으로 하여 웹에서 범용성이 뛰어나고 프론트엔드, 백엔드 모두에서 사용 가능하다. 따라서 최신 API들은 JSON을 도입하는 추세이다.
#
# JSON은 두 부분으로 구성되어 있다 : **keys, values**
#
# -Key는 표현하고자 하는 오브젝트의 특성을 나타낸다
# -Value는 Key에 대응되는 값들이다

# %% [raw]
# # JSON 데이터 예시
#
# {
#     "crust" : "original",
#     "toppings" : ["cheese", "pepperoni", "garlic"],
#     "status" : "cooking"
# }

# %% [markdown]
# 위 JSON 데이터에서, 왼쪽에 있는 것들이 Key이고, 오른쪽이 Value이다.
#
# <br><br>
# ![title](./images/JSON.PNG)
#
# 또한 value로서 또다른 JSON 오브젝트를 사용할 수 있다. (**Associate Array**)

# %% [raw]
# # Associate Array (Nested Object)
# {
#   "crust": "original",
#   "toppings": ["cheese", "pepperoni", "garlic"],
#   "status": "cooking",
#   "customer": {
#     "name": "Brian",
#     "phone": "573-111-1111"
#   }
# }

# %% [markdown]
# ##### 2. XML
#
#
#
# XML은 96년도부터 사용되어왔기에, 성숙하고 강력한 데이터 포맷이다.
#
# JSON과 마찬가지로, XML은 간단한 데이터 블럭을 가지고 있는데, 이를 '**노드(node)**'라고 부른다.
#
# XML은 항상 **뿌리 노드(Root Node)**부터 시작하여 **자식 노드(Child Node)**로 내려간다.
#
# - eXtensible Markup Language의 약자이다
# - 구조화된 데이터를 저장하는데 사용된다
# - 인터넷에서 많이 사용된다
# - 대부분 웹 스크래핑에서 XML이 자주 사용된다
# - 데이터는 두 부분으로 구성된다
#     - Markup : 텍스트 구조를 가르는 라벨
#     - Content : 문서의 실제 내용

# %% [raw]
# # XML 데이터 예시
#
# <order>
#     <crust>original</crust>
#     <toppings>
#         <topping>cheese</topping>
#         <topping>pepperoni</topping>
#         <topping>garlic</topping>
#     </toppings>
#     <status>cooking</status>
# </order>

# %% [raw]
# - Tags, Elements, Attributes
#     - 태그는 일반 라벨을 의미한다
#         - 시작 태그 <section>
#         - 종료 태그 </section>
#         - 빈 태그 <line-break />
#     - 원소들은 태그의 구체적인 예이다
#         - <Greeting\> Hello, world </Greeting\>
#     - 특징은 라벨의 원소이다
#         - <img src="jeff.jpg" alt="instructor"/>
#         - <step number="3"> Connect A to B. </step>

# %% [markdown]
# ### 데이터 요청
#
# 이제 데이터 타입을 알았으니, HTTP에서 어떻게 응용하는지 살펴보자.
#
# 우리는 앞서 헤더가 요청이나 응답의 중요한 정보를 가지고 있다고 배웠다. 마찬가지로 데이터의 형식을 알려주는 헤더인 '**Content-Type**'이 있다.
#
# 하지만 서로 주고 받는 데이터 포맷이 다를 경우 에러가 발생하는데, 이를 방지해주는 또 다른 헤더인 '**Accept**' 헤더가 있다.
#
# 이 헤더는 어떤 종류의 데이터를 받을 수 있는지 말해준다.
#
# <br><br>
#
# ![title](./images/DataFormat.PNG)
#
#
#
# ### 사용자 검증
# 서버는 클라이언트의 자격에 대해 어떻게 검증할까?
#
# 아마 누구나 웹사이트에 계정을 만들어 본 경험이 있을 것이다. 이 때 반드시 사용자 이름과 패스워드를 설정해야 하는데, 이 두 가지 정보는 나를 식별하는 표식이 되고, 이를 **Credential**이라고 부르자.
#
# 아이디와 패스워드로 로그인하는 것은 "Authentication"의 한 예이다.
# 서버에서 신원을 입증할 때, 서버에 나만이 알고 있는 정보를 전달함으로써 가능해진다.
#
# API에서도 마찬가지 방법을 사용하는데, 이 기법들을 "**Authentication Scheme**"이라고 부른다.
#
#
#
# ##### 1. 기본 검증 (Basic Authentication)
# 앞서 살펴본 로그인은 가장 기본적인 검증이다. 비록 다른 특별한 점은 없어보이지만, 이 기법은 서버가 신원을 확인할 수 있는 완벽한 방법이다.
#
# 기본 검증은 오직 사용자 이름과 비밀번호만을 요구하는데, 클라이언트는 이 두 개인 정보를 결합하여 한 가지 값으로 만들고, HTTP 요청의 헤더 중 **Authorization** 헤더에 이 정보를 함께 전달한다.
#
# 서버가 요청을 받을 때, 이 허가 헤더를 보고 기존의 것과 비교한다. 만약 신원이 일치하지 않으면 401 코드를 반송한다.
#
# 비록 기본 검증 방법이 유용하지만, 기존 웹의 계정과 API의 계정에서 같은 정보를 사용한다는 것이 항상 바람직하지는 않다. 이는 비유하자면 호텔에 묵은 손님에게 방 키가 아닌 마스터 키를 주는 것과 같다.
#
# API에서도 클라이언트가 다른 권한을 부여받아야 할 때가 있다. 이 때 아래 방법을 사용한다.
#
# ##### 2. API 키 검증 (API Key Authentication)
# API 키 검증은 API가 고유키를 통해 접근 가능하게 하여 기본 검증의 취약점을 극복하려는 기술이다.
#
# 이 방법에서, 키는 보통 문자와 숫자를 조합한 긴 문자열이고, API 관리자는 클라이언트에게 키를 제공한다.
#
# 클라이언트가 API 키로 검증을 하면, 서버는 클라이언트에 데이터를 제공하고, 더 나아가 비밀번호를 바꾸거나 계정을 삭제하는 등의 행정적 업무는 제한할 수 있게 된다.
#
# 또한 고객은 기존의 비밀번호를 사용할 필요가 없으므로 보안상으로도 더 좋다.
#
# 그럼 API 키는 어떻게 전달될까? 기본 검증과 달리, 따로 헤더가 있지는 않다. 따라서 사용자들이 각자 고유의 방법을 개척해냈는데, 몇 가지 자주 쓰이는 방법들이 있다.
#
# - 1. 클라이언트로 하여금 API키를 Auth 헤더에 보내도록 하는 것이다.
# - 2. API키를 URL에 추가하도록 하는 방법도 있다.
# - 3. 자주 쓰이지는 않지만, 요청 바디에 키를 숨겨서 함께 보내는 방법도 있다.

# %% [markdown]
# ##### 3. Open Authorization (OAuth)
# OAuth는 웹에서 가장 널리 쓰이는 검증 방법이 되어가고 있다.
#
# 과거에 정품 CD를 구매한 후, CD키를 입력하는 경험을 해봤을 것이다.
#
# 이는 UX 측면에서 상당히 좋지 않은데, 우선 물리적으로 위치하는 그 '키'를 간직하고 있어야 하고, 오타를 내어선 안되기 때문이다.
#
# 사용자들이 API 키를 사용하는 것도 비슷한 맥락으로 이해할 수 있다. 잦은 오타가 발생하고, 사용자는 서버에서 키를 받아와 클라이언트에게 주는 번거로움을 감수해야 한다.
#
# OAuth는 이러한 문제를 해결한다. 키 교환 프로세스를 자동화 한 것이 OAuth가 해결한 주요 문제이다.
#
# OAuth는 사용자가 간단한 단계를 통해 서버로부터 키를 얻을 수 있게 해준다. 사용자 입장에서 OAuth가 요구하는 것은 개인 정보 뿐이다.
#
# 다만 보이지 않는 곳에서, 클라이언트와 서버는 키를 얻기 위해 대화를 하고 있다.
#
# 현재 OAuth 1과 OAuth 2로 두 개의 버전이 있다. 하나하나 살펴보도록 하자.
#
# ##### OAuth 2
#
# 먼저 OAuth 교환의 주체들을 알아보자.
# - The User : 두 개의 웹사이트를 연결하고 싶은 사용자
# - The Client : 사용자의 데이터에 접근 권한을 얻고자 하는 웹사이트
# - The Server : 사용자의 데이터를 갖고 있는 웹사이트
#
# 그리고 더 나가기에 앞서 언급하자면, OAuth 2의 목표는 기업들이 검증 절차를 필요에 맞게끔 적용하도록 하기 위함이다.
#
# 이러한 유연성 때문에, API는 약간 다른 단계를 거칠 수도 있다. 아래 그림은 그 중 하나이고, 사용되는 기기나 기업에 따라 약간씩 다르다.
#
# - 1) 사용자는 클라이언트에 요청하여 서버에 접속하도록 한다 (보통 버튼을 눌러서)
# - 2) 클라이언트는 사용자를 서버로 보낸다( **callback URL**을 함께 보낸다)
# - 3) 사용자는 서버에 로그인하고 클아이언트에게 접근권한을 준다
# - 4) 서버는 사용자를 다시 클라이언트에게 보낸다
# - 5) 클라이언트는 코드를 교환하고 비밀 키를 교환한다
#
# ##### OAuth 1
#
# https://zapier.com/learn/apis/chapter-5-authentication-part-2/

# %% [markdown]
# # Making a Requests

# %%
import requests

# %% [markdown]
# 아래 명령어를 통해 `Response` 오브젝트를 만들어 준다.

# %%
r = requests.get("https://api.github.com/events")

# %% [markdown]
# `Requests`의 단순한 API는 모든 HTTP 리퀘스트를 아주 편리하게 해준다.
#
# 예를 들어, HTTP 리퀘스트의 네가지(PUT, DELETE, HEAD, OPTIONS) 명령어를 아래와 같이 수행할 수 있다.

# %%
r = requests.put('http://httpbin.org/put', data={'key':'value'})
r = requests.delete('http://httpbin.org/delete')
r = requests.head('http://httpbin.org/get')
r = requests.options('http://httpbin.org/get')

# %% [markdown]
# # Passing Parameters in URLs
#
# 데이터를 URL 쿼리 문자열에 전달하고 싶다면, `httpbin.org/get?key=val`처럼 URL 뒤 물음표 바로 뒤에 key/value 형식으로 전달할 수 있다.
#
# 리퀘스트는 사용자가 이러한 인자들을 `params` 키워드를 통해 문자열 딕셔너리 형태로 전달할 수 있도록 해준다.

# %%
# key1 = value1 / key2 = value2 를 전달하는 예제
payload = {'key1' :'value1', 'key2' :'value2'}
r = requests.get('http://httpbin.org/get', params=payload)

# %%
# URL이 제대로 인코드된 것을 확인할 수 있다.
print(r.url)
# Out:
# http://httpbin.org/get?key2=value2&key1=value1

# %%
# 또한 value에 리스트를 전달할 수도 있다.
payload = {'key1':'value1', 'key2' :['value2', 'value3']}
r = requests.get('http://httpbin.org/get', params=payload)
print(r.url)
# Out:
# http://httpbin.org/get?key2=value2&key2=value3&key1=value1

# %% [markdown]
# # Response Content
#
# 서버의 응답 내용을 읽어보자. 다시 깃헙의 예제를 살펴보겠다.
#
# 리퀘스트는 자동으로 서버의 컨텐츠를 디코드해준다. 대부분의 유니코드 문자열들이 바로 디코드된다.
#
# 리퀘스트를 요청할 때, `Requests`는 HTTP 헤더를 통해 응답의 인코딩에 대한 추측을 한다.
#
# `Requests`가 사용하는 인코딩 방식을 아래 명령어를 통해 알 수 있다.

# %%
r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"8033417975","type":"PushEvent","actor":{"id":41843379,"login":"bhikrj5jlmt","display_login":"bhikrj5jlmt","gravatar_id":"","url":"https://api.github.com/users/bhikrj5jlmt","avatar_url":"https://avatars.githubusercontent.com/u/41843379?"},"repo":{"id":142718067,"name":"bhikrj5jlmt/bhikrj5jlmt.github.io","url":"https://api.github.com/repos/bhikrj5jlmt/bhikrj5jlmt.github.io"},"payload":{"push_id":2755389224,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"0e97d310226f34fdd983ee50eecb5db44ad2501d","before":"d037c0e47d9b94957f070f72ab8e34c9dadeb2a1","commits":[{"sha":"0e97d310226f34fdd983ee50eecb5db44ad2501d","author":{"email":"X8iixdt0h9lu@inbox.ru","name":"Jackobs Voice"},"message":"commit","distinct":true,"url":"https://api.github.com/repos/bhikrj5jlmt/bhikrj5jlmt.github.io/commits/0e97d310226f34fdd983ee50eecb5db44ad2501d"}]},"public":true,"created_at":"2018-07-29T05:31:16Z"},{"id":"8033417973","type":"PushEvent","actor":{"id":35590162,"login":"unitydemo2","display_login":"unitydemo2","gravatar_id":"","url":"https://api.github.com/users/unitydemo2","avatar_url":"https://avatars.githubusercontent.com/u/35590162?"},"repo":{"id":139843131,"name":"unitydemo2/DocworksFE","url":"https://api.github.com/repos/unitydemo2/DocworksFE"},"payload":{"push_id":2755389223,"size":0,"distinct_size":0,"ref":"refs/heads/DW/Orphan/contentlessfe/madhu90/Manual-0","head":"8541bea0b22100fb93d567d294dcbca94b737b40","before":"8541bea0b22100fb93d567d294dcbca94b737b40","commits":[]},"public":true,"created_at":"2018-07-29T05:31:16Z"},{"id":"8033417971","type":"PushEvent","actor":{"id":37701660,"login":"tempsmolensk","display_login":"tempsmolensk","gravatar_id":"","url":"https://api.github.com/users/tempsmolensk","avatar_url":"https://avatars.githubusercontent.com/u/37701660?"},"repo":{"id":126493139,"name":"tempsmolensk/tempsmolensk.github.io","url":"https://api.github.com/repos/tempsmolensk/tempsmolensk.github.io"},"payload":{"push_id":2755389222,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"4805a19994cacf1f7ed772f35197ade691c391e7","before":"88793dc84543024ca811f8435b51c4413e1a4483","commits":[{"sha":"4805a19994cacf1f7ed772f35197ade691c391e7","author":{"email":"tempsmolensk@leonzone.ru","name":"tempsmolensk"},"message":"Update data","distinct":true,"url":"https://api.github.com/repos/tempsmolensk/tempsmolensk.github.io/commits/4805a19994cacf1f7ed772f35197ade691c391e7"}]},"public":true,"created_at":"2018-07-29T05:31:16Z"},{"id":"8033417967","type":"CreateEvent","actor":{"id":41463379,"login":"Rosemary8765","display_login":"Rosemary8765","gravatar_id":"","url":"https://api.github.com/users/Rosemary8765","avatar_url":"https://avatars.githubusercontent.com/u/41463379?"},"repo":{"id":142733714,"name":"Rosemary8765/Machine-Learning-6620-","url":"https://api.github.com/repos/Rosemary8765/Machine-Learning-6620-"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":"This repository contains files for machine learning algorithms","pusher_type":"user"},"public":true,"created_at":"2018-07-29T05:31:15Z"},{"id":"8033417964","type":"PushEvent","actor":{"id":22169029,"login":"speedtracker-bot","display_login":"speedtracker-bot","gravatar_id":"","url":"https://api.github.com/users/speedtracker-bot","avatar_url":"https://avatars.githubusercontent.com/u/22169029?"},"repo":{"id":103246937,"name":"tlgdev/speedtracker","url":"https://api.github.com/repos/tlgdev/speedtracker"},"payload":{"push_id":2755389219,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"daa348b1d2b65d6b32969146601d4be5ab44f245","before":"aeb90554867aadbe0a2d439a68ef0671ecf41cdc","commits":[{"sha":"daa348b1d2b65d6b32969146601d4be5ab44f245","author":{"email":"mail+speedtrackerbot@eduardoboucas.com","name":"SpeedTracker"},"message":"Add SpeedTracker test (scheduled)","distinct":true,"url":"https://api.github.com/repos/tlgdev/speedtracker/commits/daa348b1d2b65d6b32969146601d4be5ab44f245"}]},"public":true,"created_at":"2018-07-29T05: ...

# %%
print(r.encoding)
# change the encoding
r.encoding = 'ISO-8859-1'
print(r.encoding)
# Out:
# utf-8
# ISO-8859-1

# %% [markdown]
# ## 1 - Binary Response Content
#
# 리스폰스의 바디를 바이트의 형태로도 접근할 수 있다. (텍스트 형태가 아닐 경우)

# %%
# 여기는 텍스트라서 위와 같다
r.content
# Out:
# b'[{"id":"8033417975","type":"PushEvent","actor":{"id":41843379,"login":"bhikrj5jlmt","display_login":"bhikrj5jlmt","gravatar_id":"","url":"https://api.github.com/users/bhikrj5jlmt","avatar_url":"https://avatars.githubusercontent.com/u/41843379?"},"repo":{"id":142718067,"name":"bhikrj5jlmt/bhikrj5jlmt.github.io","url":"https://api.github.com/repos/bhikrj5jlmt/bhikrj5jlmt.github.io"},"payload":{"push_id":2755389224,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"0e97d310226f34fdd983ee50eecb5db44ad2501d","before":"d037c0e47d9b94957f070f72ab8e34c9dadeb2a1","commits":[{"sha":"0e97d310226f34fdd983ee50eecb5db44ad2501d","author":{"email":"X8iixdt0h9lu@inbox.ru","name":"Jackobs Voice"},"message":"commit","distinct":true,"url":"https://api.github.com/repos/bhikrj5jlmt/bhikrj5jlmt.github.io/commits/0e97d310226f34fdd983ee50eecb5db44ad2501d"}]},"public":true,"created_at":"2018-07-29T05:31:16Z"},{"id":"8033417973","type":"PushEvent","actor":{"id":35590162,"login":"unitydemo2","display_login":"unitydemo2","gravatar_id":"","url":"https://api.github.com/users/unitydemo2","avatar_url":"https://avatars.githubusercontent.com/u/35590162?"},"repo":{"id":139843131,"name":"unitydemo2/DocworksFE","url":"https://api.github.com/repos/unitydemo2/DocworksFE"},"payload":{"push_id":2755389223,"size":0,"distinct_size":0,"ref":"refs/heads/DW/Orphan/contentlessfe/madhu90/Manual-0","head":"8541bea0b22100fb93d567d294dcbca94b737b40","before":"8541bea0b22100fb93d567d294dcbca94b737b40","commits":[]},"public":true,"created_at":"2018-07-29T05:31:16Z"},{"id":"8033417971","type":"PushEvent","actor":{"id":37701660,"login":"tempsmolensk","display_login":"tempsmolensk","gravatar_id":"","url":"https://api.github.com/users/tempsmolensk","avatar_url":"https://avatars.githubusercontent.com/u/37701660?"},"repo":{"id":126493139,"name":"tempsmolensk/tempsmolensk.github.io","url":"https://api.github.com/repos/tempsmolensk/tempsmolensk.github.io"},"payload":{"push_id":2755389222,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"4805a19994cacf1f7ed772f35197ade691c391e7","before":"88793dc84543024ca811f8435b51c4413e1a4483","commits":[{"sha":"4805a19994cacf1f7ed772f35197ade691c391e7","author":{"email":"tempsmolensk@leonzone.ru","name":"tempsmolensk"},"message":"Update data","distinct":true,"url":"https://api.github.com/repos/tempsmolensk/tempsmolensk.github.io/commits/4805a19994cacf1f7ed772f35197ade691c391e7"}]},"public":true,"created_at":"2018-07-29T05:31:16Z"},{"id":"8033417967","type":"CreateEvent","actor":{"id":41463379,"login":"Rosemary8765","display_login":"Rosemary8765","gravatar_id":"","url":"https://api.github.com/users/Rosemary8765","avatar_url":"https://avatars.githubusercontent.com/u/41463379?"},"repo":{"id":142733714,"name":"Rosemary8765/Machine-Learning-6620-","url":"https://api.github.com/repos/Rosemary8765/Machine-Learning-6620-"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":"This repository contains files for machine learning algorithms","pusher_type":"user"},"public":true,"created_at":"2018-07-29T05:31:15Z"},{"id":"8033417964","type":"PushEvent","actor":{"id":22169029,"login":"speedtracker-bot","display_login":"speedtracker-bot","gravatar_id":"","url":"https://api.github.com/users/speedtracker-bot","avatar_url":"https://avatars.githubusercontent.com/u/22169029?"},"repo":{"id":103246937,"name":"tlgdev/speedtracker","url":"https://api.github.com/repos/tlgdev/speedtracker"},"payload":{"push_id":2755389219,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"daa348b1d2b65d6b32969146601d4be5ab44f245","before":"aeb90554867aadbe0a2d439a68ef0671ecf41cdc","commits":[{"sha":"daa348b1d2b65d6b32969146601d4be5ab44f245","author":{"email":"mail+speedtrackerbot@eduardoboucas.com","name":"SpeedTracker"},"message":"Add SpeedTracker test (scheduled)","distinct":true,"url":"https://api.github.com/repos/tlgdev/speedtracker/commits/daa348b1d2b65d6b32969146601d4be5ab44f245"}]},"public":true,"created_at":"2018-07-29T05 ...

# %%
# 예를 들어, 바이너리 데이터로부터 이미지를 그리려면 아래 코드를 사용할 수 있다.
from PIL import Image
from io import BytesIO
i = images.open(BytesIO(r.content))

# %% [markdown]
# ## 2 - JSON Response Content
#
# JSON 데이터를 처리할 경우, 내장된 JSON 디코더를 사용한다.
#
# 만약 JSON 디코딩이 실패할 경우, 예외가 발생한다. 예를 들어 204 오류(No Content)가 발생할 경우, `ValueError: No JSON object could be decoded'` 메시지가 뜬다.
#
# 하지만 `r.json()` 명령어가 응답의 성공 여부를 알려주지는 않는다. 어떤 서버들은 응답이 실패해도 JSON 오브젝트를 반환하는 경우도 있기 때문이다.
#
# 따라서 성공 여부를 확인할 때는 `r.raise_for_status()` 혹은 `r.status_code`를 사용하는게 좋다.

# %%
r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/7995581?',
#    'display_login': 'antshpra',
#    'gravatar_id': '',
#    'id': 7995581,
#    'login': 'antshpra',
#    'url': 'https://api.github.com/users/antshpra'},
#   'created_at': '2018-07-29T05:34:11Z',
#   'id': '8033420769',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/8576099?',
#    'gravatar_id': '',
#    'id': 8576099,
#    'login': 'Pratilipi',
#    'url': 'https://api.github.com/orgs/Pratilipi'},
#   'payload': {'description': None,
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': 'release-android',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 21470111,
#    'name': 'Pratilipi/pratilipi',
#    'url': 'https://api.github.com/repos/Pratilipi/pratilipi'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/10930066?',
#    'display_login': 'schelotto',
#    'gravatar_id': '',
#    'id': 10930066,
#    'login': 'schelotto',
#    'url': 'https://api.github.com/users/schelotto'},
#   'created_at': '2018-07-29T05:34:11Z',
#   'id': '8033420766',
#   'payload': {'before': 'f5d2ee15316af55063520ff4aa9391a86c981c82',
#    'commits': [{'author': {'email': 'canranxu@gmail.com', 'name': 'schelotto'},
#      'distinct': True,
#      'message': 'update',
#      'sha': '2df91f328abf00d6e769bea047bd34e867ec1abb',
#      'url': 'https://api.github.com/repos/schelotto/RVAE_PyTorch/commits/2df91f328abf00d6e769bea047bd34e867ec1abb'}],
#    'distinct_size': 1,
#    'head': '2df91f328abf00d6e769bea047bd34e867ec1abb',
#    'push_id': 2755391083,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 142673326,
#    'name': 'schelotto/RVAE_PyTorch',
#    'url': 'https://api.github.com/repos/schelotto/RVAE_PyTorch'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/245195?',
#    'display_login': 'mendieta',
#    'gravatar_id': '',
#    'id': 245195,
#    'login': 'mendieta',
#    'url': 'https://api.github.com/users/mendieta'},
#   'created_at': '2018-07-29T05:34:11Z',
#   'id': '8033420767',
#   'payload': {'action': 'started'},
#   'public': True,
#   'repo': {'id': 123526693,
#    'name': 'FranPitri/flutter_redux_boilerplate',
#    'url': 'https://api.github.com/repos/FranPitri/flutter_redux_boilerplate'},
#   'type': 'WatchEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/35590162?',
#    'display_login': 'unitydemo2',
#    'gravatar_id': '',
#    'id': 35590162,
#    'login': 'unitydemo2',
#    'url': 'https://api.github.com/users/unitydemo2'},
#   'created_at': '2018-07-29T05:34:11Z',
#   'id': '8033420760',
#   'payload': {'before': 'b546775d7b7e9f9723a6611b2e909aa9f69e344e',
#    'commits': [],
#    'distinct_size': 0,
#    'head': 'b546775d7b7e9f9723a6611b2e909aa9f69e344e',
#    'push_id': 2755391080,
#    'ref': 'refs/heads/DW/DocWorksManual3/project_github/github_dist/Manual-0',
#    'size': 0},
#   'public': True,
#   'repo': {'id': 118083636,
#    'name': 'unitydemo2/Docworks',
#    'url': 'https://api.github.com/repos/unitydemo2/Docworks'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/824507?',
#    'display_login': 'dclong',
#    'gravatar_id': '',
#    'id': 824507,
#    'login': 'dclong',
#    'url': 'https://api.github.com/users/dclong'},
#   'created_at': '2018-07-29T05:34:11Z',
#   'id': '8033420759',
#   'payload': {'action': 'opened',
#    'number': 1,
#    'pull_request': {'_links': {'comments': {'href': 'https://api.github.com/repos/dclong/docker-jupyter/issues/1/comments'},
#      'commits': {'href': 'https://api.github.com/repos/dclong/docker-jupyter/pulls/1/commits'},
#      'html': {'href': 'https://github.com/dclong/docker-jupyter/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/dclong/docker-jupyter/issues/1'},
#      'review_comment': {'href': 'https://api.github.com/repos/dclong/docker-jupyter/pulls/comments{/number}'},
#      'review_comments': {'href': 'https://api.github.com/repos/dclong/docker-jupyter/pulls/1/comments'},
#      'self': {'href': 'https://api.github.com/repos/dclong/docker-jupyter/pulls/1'},
#      'statuses': {'href': 'https://api.github.com/repos/dclong/docker-jupyter/statuses/aa9b242dbd49980c3820e4818d0f231e4df7718b'}},
#     'additions': 11,
#     'assignee': None,
#     'assignees': [],
#     'author_association': 'OWNER',
#     'base': {'label': 'dclong:master',
#      'ref': 'master',
#      'repo': {'archive_url': 'https://api.github.com/repos/dclong/docker-jupyter/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/dclong/docker-jupyter/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/dclong/docker-jupyter/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/dclong/docker-jupyter/branches{/branch}',
#       'clone_url': 'https://github.com/dclong/docker-jupyter.git',
#       'collaborators_url': 'https://api.github.com/repos/dclong/docker-jupyter/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/dclong/docker-jupyter/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/dclong/docker-jupyter/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/dclong/docker-jupyter/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/dclong/docker-jupyter/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/dclong/docker-jupyter/contributors',
#       'created_at': '2018-01-02T15:01:01Z',
#       'default_branch': 'master',
#       'deployments_url': 'https://api.github.com/repos/dclong/docker-jupyter/deployments',
#       'description': None,
#       'downloads_url': 'https://api.github.com/repos/dclong/docker-jupyter/downloads',
#       'events_url': 'https://api.github.com/repos/dclong/docker-jupyter/events',
#       'fork': False,
#       'forks': 0,
#       'forks_count': 0,
#       'forks_url': 'https://api.github.com/repos/dclong/docker-jupyter/forks',
#       'full_name': 'dclong/docker-jupyter',
#       'git_commits_url': 'https://api.github.com/repos/dclong/docker-jupyter/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/dclong/docker-jupyter/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/dclong/docker-jupyter/git/tags{/sha}',
#       'git_url': 'git://github.com/dclong/docker-jupyter.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': None,
#       'hooks_url': 'https://api.github.com/repos/dclong/docker-jupyter/hooks',
#       'html_url': 'https://github.com/dclong/docker-jupyter',
#       'id': 116026703,
#       'issue_comment_url': 'https://api.github.com/repos/dclong/docker-jupyter/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/dclong/docker-jupyter/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/dclong/docker-jupyter/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/dclong/docker-jupyter/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/dclong/docker-jupyter/labels{/name}',
#       'language': 'Shell',
#       'languages_url': 'https://api.github.com/repos/dclong/docker-jupyter/languages',
#       'license': None,
#       'merges_url': 'https://api.github.com/repos/dclong/docker-jupyter/merges',
#       'milestones_url': 'https://api.github.com/repos/dclong/docker-jupyter/milestones{/number}',
#       'mirror_url': None,
#       'name': 'docker-jupyter',
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTYwMjY3MDM=',
#       'notifications_url': 'https://api.github.com/repos/dclong/docker-jupyter/notifications{?since,all,participating}',
#       'open_issues': 1,
#       'open_issues_count': 1,
#       'owner': {'avatar_url': 'https://avatars0.githubusercontent.com/u/824507?v=4',
#        'events_url': 'https://api.github.com/users/dclong/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/dclong/followers',
#        'following_url': 'https://api.github.com/users/dclong/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/dclong/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/dclong',
#        'id': 824507,
#        'login': 'dclong',
#        'node_id': 'MDQ6VXNlcjgyNDUwNw==',
#        'organizations_url': 'https://api.github.com/users/dclong/orgs',
#        'received_events_url': 'https://api.github.com/users/dclong/received_events',
#        'repos_url': 'https://api.github.com/users/dclong/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/dclong/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/dclong/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/dclong'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/dclong/docker-jupyter/pulls{/number}',
#       'pushed_at': '2018-07-29T05:33:32Z',
#       'releases_url': 'https://api.github.com/repos/dclong/docker-jupyter/releases{/id}',
#       'size': 15,
#       'ssh_url': 'git@github.com:dclong/docker-jupyter.git',
#       'stargazers_count': 0,
#       'stargazers_url': 'https://api.github.com/repos/dclong/docker-jupyter/stargazers',
#       'statuses_url': 'https://api.github.com/repos/dclong/docker-jupyter/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/dclong/docker-jupyter/subscribers',
#       'subscription_url': 'https://api.github.com/repos/dclong/docker-jupyter/subscription',
#       'svn_url': 'https://github.com/dclong/docker-jupyter',
#       'tags_url': 'https://api.github.com/repos/dclong/docker-jupyter/tags',
#       'teams_url': 'https://api.github.com/repos/dclong/docker-jupyter/teams',
#       'trees_url': 'https://api.github.com/repos/dclong/docker-jupyter/git/trees{/sha}',
#       'updated_at': '2018-07-21T16:26:44Z',
#       'url': 'https://api.github.com/repos/dclong/docker-jupyter',
#       'watchers': 0,
#       'watchers_count': 0},
#      'sha': 'ff276e9a16c34a17f8cc5e2e6d801bf2032aded3',
#      'user': {'avatar_url': 'https://avatars0.githubusercontent.com/u/824507?v=4',
#       'events_url': 'https://api.github.com/users/dclong/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/dclong/followers',
#       'following_url': 'https://api.github.com/users/dclong/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dclong/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/dclong',
#       'id': 824507,
#       'login': 'dclong',
#       'node_id': 'MDQ6VXNlcjgyNDUwNw==',
#       'organizations_url': 'https://api.github.com/users/dclong/orgs',
#       'received_events_url': 'https://api.github.com/users/dclong/received_events',
#       'repos_url': 'https://api.github.com/users/dclong/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/dclong/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dclong/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/dclong'}},
#     'body': '',
#     'changed_files': 2,
#     'closed_at': None,
#     'comments': 0,
#     'comments_url': 'https://api.github.com/repos/dclong/docker-jupyter/issues/1/comments',
#     'commits': 2,
#     'commits_url': 'https://api.github.com/repos/dclong/docker-jupyter/pulls/1/commits',
#     'created_at': '2018-07-29T05:34:11Z',
#     'deletions': 12,
#     'diff_url': 'https://github.com/dclong/docker-jupyter/pull/1.diff',
#     'head': {'label': 'dclong:patch',
#      'ref': 'patch',
#      'repo': {'archive_url': 'https://api.github.com/repos/dclong/docker-jupyter/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/dclong/docker-jupyter/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/dclong/docker-jupyter/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/dclong/docker-jupyter/branches{/branch}',
#       'clone_url': 'https://github.com/dclong/docker-jupyter.git',
#       'collaborators_url': 'https://api.github.com/repos/dclong/docker-jupyter/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/dclong/docker-jupyter/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/dclong/docker-jupyter/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/dclong/docker-jupyter/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/dclong/docker-jupyter/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/dclong/docker-jupyter/contributors',
#       'created_at': '2018-01-02T15:01:01Z',
#       'default_branch': 'master',
#       'deployments_url': 'https://api.github.com/repos/dclong/docker-jupyter/deployments',
#       'description': None,
#       'downloads_url': 'https://api.github.com/repos/dclong/docker-jupyter/downloads',
#       'events_url': 'https://api.github.com/repos/dclong/docker-jupyter/events',
#       'fork': False,
#       'forks': 0,
#       'forks_count': 0,
#       'forks_url': 'https://api.github.com/repos/dclong/docker-jupyter/forks',
#       'full_name': 'dclong/docker-jupyter',
#       'git_commits_url': 'https://api.github.com/repos/dclong/docker-jupyter/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/dclong/docker-jupyter/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/dclong/docker-jupyter/git/tags{/sha}',
#       'git_url': 'git://github.com/dclong/docker-jupyter.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': None,
#       'hooks_url': 'https://api.github.com/repos/dclong/docker-jupyter/hooks',
#       'html_url': 'https://github.com/dclong/docker-jupyter',
#       'id': 116026703,
#       'issue_comment_url': 'https://api.github.com/repos/dclong/docker-jupyter/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/dclong/docker-jupyter/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/dclong/docker-jupyter/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/dclong/docker-jupyter/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/dclong/docker-jupyter/labels{/name}',
#       'language': 'Shell',
#       'languages_url': 'https://api.github.com/repos/dclong/docker-jupyter/languages',
#       'license': None,
#       'merges_url': 'https://api.github.com/repos/dclong/docker-jupyter/merges',
#       'milestones_url': 'https://api.github.com/repos/dclong/docker-jupyter/milestones{/number}',
#       'mirror_url': None,
#       'name': 'docker-jupyter',
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTYwMjY3MDM=',
#       'notifications_url': 'https://api.github.com/repos/dclong/docker-jupyter/notifications{?since,all,participating}',
#       'open_issues': 1,
#       'open_issues_count': 1,
#       'owner': {'avatar_url': 'https://avatars0.githubusercontent.com/u/824507?v=4',
#        'events_url': 'https://api.github.com/users/dclong/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/dclong/followers',
#        'following_url': 'https://api.github.com/users/dclong/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/dclong/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/dclong',
#        'id': 824507,
#        'login': 'dclong',
#        'node_id': 'MDQ6VXNlcjgyNDUwNw==',
#        'organizations_url': 'https://api.github.com/users/dclong/orgs',
#        'received_events_url': 'https://api.github.com/users/dclong/received_events',
#        'repos_url': 'https://api.github.com/users/dclong/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/dclong/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/dclong/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/dclong'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/dclong/docker-jupyter/pulls{/number}',
#       'pushed_at': '2018-07-29T05:33:32Z',
#       'releases_url': 'https://api.github.com/repos/dclong/docker-jupyter/releases{/id}',
#       'size': 15,
#       'ssh_url': 'git@github.com:dclong/docker-jupyter.git',
#       'stargazers_count': 0,
#       'stargazers_url': 'https://api.github.com/repos/dclong/docker-jupyter/stargazers',
#       'statuses_url': 'https://api.github.com/repos/dclong/docker-jupyter/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/dclong/docker-jupyter/subscribers',
#       'subscription_url': 'https://api.github.com/repos/dclong/docker-jupyter/subscription',
#       'svn_url': 'https://github.com/dclong/docker-jupyter',
#       'tags_url': 'https://api.github.com/repos/dclong/docker-jupyter/tags',
#       'teams_url': 'https://api.github.com/repos/dclong/docker-jupyter/teams',
#       'trees_url': 'https://api.github.com/repos/dclong/docker-jupyter/git/trees{/sha}',
#       'updated_at': '2018-07-21T16:26:44Z',
#       'url': 'https://api.github.com/repos/dclong/docker-jupyter',
#       'watchers': 0,
#       'watchers_count': 0},
#      'sha': 'aa9b242dbd49980c3820e4818d0f231e4df7718b',
#      'user': {'avatar_url': 'https://avatars0.githubusercontent.com/u/824507?v=4',
#       'events_url': 'https://api.github.com/users/dclong/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/dclong/followers',
#       'following_url': 'https://api.github.com/users/dclong/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dclong/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/dclong',
#       'id': 824507,
#       'login': 'dclong',
#       'node_id': 'MDQ6VXNlcjgyNDUwNw==',
#       'organizations_url': 'https://api.github.com/users/dclong/orgs',
#       'received_events_url': 'https://api.github.com/users/dclong/received_events',
#       'repos_url': 'https://api.github.com/users/dclong/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/dclong/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dclong/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/dclong'}},
#     'html_url': 'https://github.com/dclong/docker-jupyter/pull/1',
#     'id': 204625635,
#     'issue_url': 'https://api.github.com/repos/dclong/docker-jupyter/issues/1',
#     'labels': [],
#     'locked': False,
#     'maintainer_can_modify': False,
#     'merge_commit_sha': None,
#     'mergeable': None,
#     'mergeable_state': 'unknown',
#     'merged': False,
#     'merged_at': None,
#     'merged_by': None,
#     'milestone': None,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MjA0NjI1NjM1',
#     'number': 1,
#     'patch_url': 'https://github.com/dclong/docker-jupyter/pull/1.patch',
#     'rebaseable': None,
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'review_comment_url': 'https://api.github.com/repos/dclong/docker-jupyter/pulls/comments{/number}',
#     'review_comments': 0,
#     'review_comments_url': 'https://api.github.com/repos/dclong/docker-jupyter/pulls/1/comments',
#     'state': 'open',
#     'statuses_url': 'https://api.github.com/repos/dclong/docker-jupyter/statuses/aa9b242dbd49980c3820e4818d0f231e4df7718b',
#     'title': 'Patch',
#     'updated_at': '2018-07-29T05:34:11Z',
#     'url': 'https://api.github.com/repos/dclong/docker-jupyter/pulls/1',
#     'user': {'avatar_url': 'https://avatars0.githubusercontent.com/u/824507?v=4',
#      'events_url': 'https://api.github.com/users/dclong/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/dclong/followers',
#      'following_url': 'https://api.github.com/users/dclong/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dclong/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/dclong',
#      'id': 824507,
#      'login': 'dclong',
#      'node_id': 'MDQ6VXNlcjgyNDUwNw==',
#      'organizations_url': 'https://api.github.com/users/dclong/orgs',
#      'received_events_url': 'https://api.github.com/users/dclong/received_events',
#      'repos_url': 'https://api.github.com/users/dclong/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/dclong/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dclong/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/dclong'}}},
#   'public': True,
#   'repo': {'id': 116026703,
#    'name': 'dclong/docker-jupyter',
#    'url': 'https://api.github.com/repos/dclong/docker-jupyter'},
#   'type': 'PullRequestEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/35246533?',
#    'display_login': '19900905',
#    'gravatar_id': '',
#    'id': 35246533,
#    'login': '19900905',
#    'url': 'https://api.github.com/users/19900905'},
#   'created_at': '2018-07-29T05:34:11Z',
#   'id': '8033420758',
#   'payload': {'description': None,
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': None,
#    'ref_type': 'repository'},
#   'public': True,
#   'repo': {'id': 142733880,
#    'name': '19900905/sts-in-action',
#    'url': 'https://api.github.com/repos/19900905/sts-in-action'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/21124811?',
#    'display_login': '389093982',
#    'gravatar_id': '',
#    'id': 21124811,
#    'login': '389093982',
#    'url': 'https://api.github.com/users/389093982'},
#   'created_at': '2018-07-29T05:34:11Z',
#   'id': '8033420757',
#   'payload': {'description': 'github',
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': None,
#    'ref_type': 'repository'},
#   'public': True,
#   'repo': {'id': 142733879,
#    'name': '389093982/isoft_v1.0.1',
#    'url': 'https://api.github.com/repos/389093982/isoft_v1.0.1'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/10701211?',
#    'display_login': 'stinkbutt',
#    'gravatar_id': '',
#    'id': 10701211,
#    'login': 'stinkbutt',
#    'url': 'https://api.github.com/users/stinkbutt'},
#   'created_at': '2018-07-29T05:34:11Z',
#   'id': '8033420755',
#   'payload': {'description': None,
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': None,
#    'ref_type': 'repository'},
#   'public': True,
#   'repo': {'id': 142733878,
#    'name': 'stinkbutt/aquarium',
#    'url': 'https://api.github.com/repos/stinkbutt/aquarium'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/988437?',
#    'display_login': 'eyeplum',
#    'gravatar_id': '',
#    'id': 988437,
#    'login': 'eyeplum',
#    'url': 'https://api.github.com/users/eyeplum'},
#   'created_at': '2018-07-29T05:34:11Z',
#   'id': '8033420753',
#   'payload': {'description': None,
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': 'master',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 142733857,
#    'name': 'eyeplum/Qt-TreeView-Resizing-Examples',
#    'url': 'https://api.github.com/repos/eyeplum/Qt-TreeView-Resizing-Examples'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/15913224?',
#    'display_login': 'tumble1999',
#    'gravatar_id': '',
#    'id': 15913224,
#    'login': 'tumble1999',
#    'url': 'https://api.github.com/users/tumble1999'},
#   'created_at': '2018-07-29T05:34:11Z',
#   'id': '8033420752',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/22372181?',
#    'gravatar_id': '',
#    'id': 22372181,
#    'login': 'tumblenet',
#    'url': 'https://api.github.com/orgs/tumblenet'},
#   'payload': {'before': 'b7cca9f7e4a5b70bf9b20d921ccfa7751e8c8901',
#    'commits': [{'author': {'email': 'tumblegamer@gmail.com', 'name': 'Tumble'},
#      'distinct': True,
#      'message': 'server auto-save',
#      'sha': '8b0dbd5fecba52bfa347f29083e87e2766174cf1',
#      'url': 'https://api.github.com/repos/tumblenet/TumbleCraftJavaTest/commits/8b0dbd5fecba52bfa347f29083e87e2766174cf1'}],
#    'distinct_size': 1,
#    'head': '8b0dbd5fecba52bfa347f29083e87e2766174cf1',
#    'push_id': 2755391077,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 130900283,
#    'name': 'tumblenet/TumbleCraftJavaTest',
#    'url': 'https://api.github.com/repos/tumblenet/TumbleCraftJavaTest'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/31773746?',
#    'display_login': 'LennonChin',
#    'gravatar_id': '',
#    'id': 31773746,
#    'login': 'LennonChin',
#    'url': 'https://api.github.com/users/LennonChin'},
#   'created_at': '2018-07-29T05:34:11Z',
#   'id': '8033420749',
#   'payload': {'before': '1465f201d1ac5014d30fe98cbf3b5d1563b8ffa5',
#    'commits': [{'author': {'email': 'i@coderap.com', 'name': 'LennonChin'},
#      'distinct': True,
#      'message': "1, basic Array and it's tests;",
#      'sha': 'b6015947ba28ce96d73939813d78b02beadf00ba',
#      'url': 'https://api.github.com/repos/LennonChin/Data-Structure-Practices/commits/b6015947ba28ce96d73939813d78b02beadf00ba'}],
#    'distinct_size': 1,
#    'head': 'b6015947ba28ce96d73939813d78b02beadf00ba',
#    'push_id': 2755391075,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 142733060,
#    'name': 'LennonChin/Data-Structure-Practices',
#    'url': 'https://api.github.com/repos/LennonChin/Data-Structure-Practices'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/7953560?',
#    'display_login': 'bryndyment',
#    'gravatar_id': '',
#    'id': 7953560,
#    'login': 'bryndyment',
#    'url': 'https://api.github.com/users/bryndyment'},
#   'created_at': '2018-07-29T05:34:11Z',
#   'id': '8033420748',
#   'payload': {'description': None,
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': None,
#    'ref_type': 'repository'},
#   'public': True,
#   'repo': {'id': 142733877,
#    'name': 'bryndyment/michelamacfarlane',
#    'url': 'https://api.github.com/repos/bryndyment/michelamacfarlane'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/41539413?',
#    'display_login': 'catchme94',
#    'gravatar_id': '',
#    'id': 41539413,
#    'login': 'catchme94',
#    'url': 'https://api.github.com/users/catchme94'},
#   'created_at': '2018-07-29T05:34:11Z',
#   'id': '8033420747',
#   'payload': {'before': '98ab3584a463fd5ff669f0f4c274f796432890c6',
#    'commits': [{'author': {'email': 'ongjunxiang@192.168.1.18',
#       'name': 'ongjunxiang'},
#      'distinct': True,
#      'message': 'Glossary changes by ongjunxiang',
#      'sha': '74c99b8f846a89338623b68174c344f38090bc37',
#      'url': 'https://api.github.com/repos/atlas-studios/CCSSZZCCJJZZSS/commits/74c99b8f846a89338623b68174c344f38090bc37'}],
#    'distinct_size': 1,
#    'head': '74c99b8f846a89338623b68174c344f38090bc37',
#    'push_id': 2755391074,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 141912095,
#    'name': 'atlas-studios/CCSSZZCCJJZZSS',
#    'url': 'https://api.github.com/repos/atlas-studios/CCSSZZCCJJZZSS'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/38429025?',
#    'display_login': 'chuan12',
#    'gravatar_id': '',
#    'id': 38429025,
#    'login': 'chuan12',
#    'url': 'https://api.github.com/users/chuan12'},
#   'created_at': '2018-07-29T05:34:11Z',
#   'id': '8033420746',
#   'payload': {'before': '6aee953ebf3ab96caccab7d80242b3a9fd4a0251',
#    'commits': [{'author': {'email': '38429025+chuan12@users.noreply.github.com',
#       'name': 'chuan12'},
#      'distinct': True,
#      'message': 'Update data.json',
#      'sha': '58ac83362d137442ed26c9d8ae29f037a6c07bc2',
#      'url': 'https://api.github.com/repos/chuan12/shenzhouzd/commits/58ac83362d137442ed26c9d8ae29f037a6c07bc2'}],
#    'distinct_size': 1,
#    'head': '58ac83362d137442ed26c9d8ae29f037a6c07bc2',
#    'push_id': 2755391073,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 129750934,
#    'name': 'chuan12/shenzhouzd',
#    'url': 'https://api.github.com/repos/chuan12/shenzhouzd'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/30883783?',
#    'display_login': 'x1matrix',
#    'gravatar_id': '',
#    'id': 30883783,
#    'login': 'x1matrix',
#    'url': 'https://api.github.com/users/x1matrix'},
#   'created_at': '2018-07-29T05:34:11Z',
#   'id': '8033420743',
#   'payload': {'forkee': {'archive_url': 'https://api.github.com/repos/x1matrix/algs4/{archive_format}{/ref}',
#     'archived': False,
#     'assignees_url': 'https://api.github.com/repos/x1matrix/algs4/assignees{/user}',
#     'blobs_url': 'https://api.github.com/repos/x1matrix/algs4/git/blobs{/sha}',
#     'branches_url': 'https://api.github.com/repos/x1matrix/algs4/branches{/branch}',
#     'clone_url': 'https://github.com/x1matrix/algs4.git',
#     'collaborators_url': 'https://api.github.com/repos/x1matrix/algs4/collaborators{/collaborator}',
#     'comments_url': 'https://api.github.com/repos/x1matrix/algs4/comments{/number}',
#     'commits_url': 'https://api.github.com/repos/x1matrix/algs4/commits{/sha}',
#     'compare_url': 'https://api.github.com/repos/x1matrix/algs4/compare/{base}...{head}',
#     'contents_url': 'https://api.github.com/repos/x1matrix/algs4/contents/{+path}',
#     'contributors_url': 'https://api.github.com/repos/x1matrix/algs4/contributors',
#     'created_at': '2018-07-29T05:34:10Z',
#     'default_branch': 'master',
#     'deployments_url': 'https://api.github.com/repos/x1matrix/algs4/deployments',
#     'description': 'Algorithms, 4th edition textbook code and libraries',
#     'downloads_url': 'https://api.github.com/repos/x1matrix/algs4/downloads',
#     'events_url': 'https://api.github.com/repos/x1matrix/algs4/events',
#     'fork': True,
#     'forks': 0,
#     'forks_count': 0,
#     'forks_url': 'https://api.github.com/repos/x1matrix/algs4/forks',
#     'full_name': 'x1matrix/algs4',
#     'git_commits_url': 'https://api.github.com/repos/x1matrix/algs4/git/commits{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/x1matrix/algs4/git/refs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/x1matrix/algs4/git/tags{/sha}',
#     'git_url': 'git://github.com/x1matrix/algs4.git',
#     'has_downloads': True,
#     'has_issues': False,
#     'has_pages': False,
#     'has_projects': True,
#     'has_wiki': True,
#     'homepage': 'http://algs4.cs.princeton.edu/code/',
#     'hooks_url': 'https://api.github.com/repos/x1matrix/algs4/hooks',
#     'html_url': 'https://github.com/x1matrix/algs4',
#     'id': 142733876,
#     'issue_comment_url': 'https://api.github.com/repos/x1matrix/algs4/issues/comments{/number}',
#     'issue_events_url': 'https://api.github.com/repos/x1matrix/algs4/issues/events{/number}',
#     'issues_url': 'https://api.github.com/repos/x1matrix/algs4/issues{/number}',
#     'keys_url': 'https://api.github.com/repos/x1matrix/algs4/keys{/key_id}',
#     'labels_url': 'https://api.github.com/repos/x1matrix/algs4/labels{/name}',
#     'language': None,
#     'languages_url': 'https://api.github.com/repos/x1matrix/algs4/languages',
#     'license': {'key': 'gpl-3.0',
#      'name': 'GNU General Public License v3.0',
#      'node_id': 'MDc6TGljZW5zZTk=',
#      'spdx_id': 'GPL-3.0',
#      'url': 'https://api.github.com/licenses/gpl-3.0'},
#     'merges_url': 'https://api.github.com/repos/x1matrix/algs4/merges',
#     'milestones_url': 'https://api.github.com/repos/x1matrix/algs4/milestones{/number}',
#     'mirror_url': None,
#     'name': 'algs4',
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNDI3MzM4NzY=',
#     'notifications_url': 'https://api.github.com/repos/x1matrix/algs4/notifications{?since,all,participating}',
#     'open_issues': 0,
#     'open_issues_count': 0,
#     'owner': {'avatar_url': 'https://avatars0.githubusercontent.com/u/30883783?v=4',
#      'events_url': 'https://api.github.com/users/x1matrix/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/x1matrix/followers',
#      'following_url': 'https://api.github.com/users/x1matrix/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/x1matrix/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/x1matrix',
#      'id': 30883783,
#      'login': 'x1matrix',
#      'node_id': 'MDQ6VXNlcjMwODgzNzgz',
#      'organizations_url': 'https://api.github.com/users/x1matrix/orgs',
#      'received_events_url': 'https://api.github.com/users/x1matrix/received_events',
#      'repos_url': 'https://api.github.com/users/x1matrix/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/x1matrix/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/x1matrix/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/x1matrix'},
#     'private': False,
#     'public': True,
#     'pulls_url': 'https://api.github.com/repos/x1matrix/algs4/pulls{/number}',
#     'pushed_at': '2018-06-24T12:00:18Z',
#     'releases_url': 'https://api.github.com/repos/x1matrix/algs4/releases{/id}',
#     'size': 1016,
#     'ssh_url': 'git@github.com:x1matrix/algs4.git',
#     'stargazers_count': 0,
#     'stargazers_url': 'https://api.github.com/repos/x1matrix/algs4/stargazers',
#     'statuses_url': 'https://api.github.com/repos/x1matrix/algs4/statuses/{sha}',
#     'subscribers_url': 'https://api.github.com/repos/x1matrix/algs4/subscribers',
#     'subscription_url': 'https://api.github.com/repos/x1matrix/algs4/subscription',
#     'svn_url': 'https://github.com/x1matrix/algs4',
#     'tags_url': 'https://api.github.com/repos/x1matrix/algs4/tags',
#     'teams_url': 'https://api.github.com/repos/x1matrix/algs4/teams',
#     'trees_url': 'https://api.github.com/repos/x1matrix/algs4/git/trees{/sha}',
#     'updated_at': '2018-07-29T00:59:43Z',
#     'url': 'https://api.github.com/repos/x1matrix/algs4',
#     'watchers': 0,
#     'watchers_count': 0}},
#   'public': True,
#   'repo': {'id': 41667394,
#    'name': 'kevin-wayne/algs4',
#    'url': 'https://api.github.com/repos/kevin-wayne/algs4'},
#   'type': 'ForkEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/29452781?',
#    'display_login': 'ntbpm',
#    'gravatar_id': '',
#    'id': 29452781,
#    'login': 'ntbpm',
#    'url': 'https://api.github.com/users/ntbpm'},
#   'created_at': '2018-07-29T05:34:10Z',
#   'id': '8033420742',
#   'payload': {'before': 'dc68f63abc24796c463918b011aff7729a1e7cd0',
#    'commits': [{'author': {'email': 'ixyz169@163.com', 'name': 'ntbpm'},
#      'distinct': True,
#      'message': '123',
#      'sha': 'ba0ad6c017d8adc6289bc9f6a46e7cbf26279670',
#      'url': 'https://api.github.com/repos/ntbpm/testv/commits/ba0ad6c017d8adc6289bc9f6a46e7cbf26279670'}],
#    'distinct_size': 1,
#    'head': 'ba0ad6c017d8adc6289bc9f6a46e7cbf26279670',
#    'push_id': 2755391070,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 94426206,
#    'name': 'ntbpm/testv',
#    'url': 'https://api.github.com/repos/ntbpm/testv'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/1094541?',
#    'display_login': 'stephenhu',
#    'gravatar_id': '',
#    'id': 1094541,
#    'login': 'stephenhu',
#    'url': 'https://api.github.com/users/stephenhu'},
#   'created_at': '2018-07-29T05:34:10Z',
#   'id': '8033420739',
#   'payload': {'before': '715ce382107fd96d0576760274676c5def4553ab',
#    'commits': [{'author': {'email': 'epynonymous@outlook.com',
#       'name': 'stephenhu'},
#      'distinct': True,
#      'message': 'set default rank',
#      'sha': 'c715bc9378f945c2b1d7807f7b3ab48fcaab3fc6',
#      'url': 'https://api.github.com/repos/stephenhu/gogetsdone/commits/c715bc9378f945c2b1d7807f7b3ab48fcaab3fc6'}],
#    'distinct_size': 1,
#    'head': 'c715bc9378f945c2b1d7807f7b3ab48fcaab3fc6',
#    'push_id': 2755391067,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 137034597,
#    'name': 'stephenhu/gogetsdone',
#    'url': 'https://api.github.com/repos/stephenhu/gogetsdone'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/41517164?',
#    'display_login': 'c1d5dc29-94f0-4b46-bc0a-397a2885eade',
#    'gravatar_id': '',
#    'id': 41517164,
#    'login': 'c1d5dc29-94f0-4b46-bc0a-397a2885eade',
#    'url': 'https://api.github.com/users/c1d5dc29-94f0-4b46-bc0a-397a2885eade'},
#   'created_at': '2018-07-29T05:34:10Z',
#   'id': '8033420738',
#   'payload': {'before': '29058cb69fe1b9a4d0d01fe8d628ef24647b012e',
#    'commits': [{'author': {'email': 'c1d5dc29-94f0-4b46-bc0a-397a2885eade',
#       'name': 'c1d5dc29-94f0-4b46-bc0a-397a2885eade'},
#      'distinct': True,
#      'message': '7536ace7-76ff-48ab-ad61-d7a2c300bd29',
#      'sha': 'f3e6d781f4f1006de1d3b27432d1b1f8a4697482',
#      'url': 'https://api.github.com/repos/c1d5dc29-94f0-4b46-bc0a-397a2885eade/c1d5dc29-94f0-4b46-bc0a-397a2885eade/commits/f3e6d781f4f1006de1d3b27432d1b1f8a4697482'}],
#    'distinct_size': 1,
#    'head': 'f3e6d781f4f1006de1d3b27432d1b1f8a4697482',
#    'push_id': 2755391066,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 141827496,
#    'name': 'c1d5dc29-94f0-4b46-bc0a-397a2885eade/c1d5dc29-94f0-4b46-bc0a-397a2885eade',
#    'url': 'https://api.github.com/repos/c1d5dc29-94f0-4b46-bc0a-397a2885eade/c1d5dc29-94f0-4b46-bc0a-397a2885eade'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/18260229?',
#    'display_login': 'slevy85',
#    'gravatar_id': '',
#    'id': 18260229,
#    'login': 'slevy85',
#    'url': 'https://api.github.com/users/slevy85'},
#   'created_at': '2018-07-29T05:34:10Z',
#   'id': '8033420737',
#   'payload': {'description': 'A React.js implementation of the Flipboard page swipe.',
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': 'start-page-change-event',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 130501924,
#    'name': 'slevy85/react-flip-page',
#    'url': 'https://api.github.com/repos/slevy85/react-flip-page'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/35590162?',
#    'display_login': 'unitydemo2',
#    'gravatar_id': '',
#    'id': 35590162,
#    'login': 'unitydemo2',
#    'url': 'https://api.github.com/users/unitydemo2'},
#   'created_at': '2018-07-29T05:34:10Z',
#   'id': '8033420733',
#   'payload': {'before': '469186ebf80b8304d142c08e0efc9ad16376fdf0',
#    'commits': [],
#    'distinct_size': 0,
#    'head': '469186ebf80b8304d142c08e0efc9ad16376fdf0',
#    'push_id': 2755391064,
#    'ref': 'refs/heads/DW/DocworksManual2/21may0506pm/dist001/Manual-0',
#    'size': 0},
#   'public': True,
#   'repo': {'id': 118083636,
#    'name': 'unitydemo2/Docworks',
#    'url': 'https://api.github.com/repos/unitydemo2/Docworks'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/37983994?',
#    'display_login': 'impks27',
#    'gravatar_id': '',
#    'id': 37983994,
#    'login': 'impks27',
#    'url': 'https://api.github.com/users/impks27'},
#   'created_at': '2018-07-29T05:34:10Z',
#   'id': '8033420735',
#   'payload': {'description': None,
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': None,
#    'ref_type': 'repository'},
#   'public': True,
#   'repo': {'id': 142733875,
#    'name': 'impks27/python-samples',
#    'url': 'https://api.github.com/repos/impks27/python-samples'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/39821544?',
#    'display_login': 'pz0995',
#    'gravatar_id': '',
#    'id': 39821544,
#    'login': 'pz0995',
#    'url': 'https://api.github.com/users/pz0995'},
#   'created_at': '2018-07-29T05:34:10Z',
#   'id': '8033420732',
#   'payload': {'before': '3928d11ad6d75bde3232c7f3af291a76934659ac',
#    'commits': [{'author': {'email': 'tiffanyleigh.10@gmail.com',
#       'name': 'Tiffany Leigh'},
#      'distinct': True,
#      'message': 'automatically backed up by learn',
#      'sha': 'c124ed6670bbe03ae89968db4f581a4fb58ea3e2',
#      'url': 'https://api.github.com/repos/pz0995/ruby-advanced-class-methods-lab-v-000/commits/c124ed6670bbe03ae89968db4f581a4fb58ea3e2'}],
#    'distinct_size': 1,
#    'head': 'c124ed6670bbe03ae89968db4f581a4fb58ea3e2',
#    'push_id': 2755391063,
#    'ref': 'refs/heads/wip',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 142089477,
#    'name': 'pz0995/ruby-advanced-class-methods-lab-v-000',
#    'url': 'https://api.github.com/repos/pz0995/ruby-advanced-class-methods-lab-v-000'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/827338?',
#    'display_login': 'ewgenius',
#    'gravatar_id': '',
#    'id': 827338,
#    'login': 'ewgenius',
#    'url': 'https://api.github.com/users/ewgenius'},
#   'created_at': '2018-07-29T05:34:10Z',
#   'id': '8033420729',
#   'payload': {'description': 'React edition of https://material.io/tools/color',
#    'master_branch': 'master',
#    'pusher_type': 'user',
#    'ref': 'master',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 142733832,
#    'name': 'ewgenius/material-color-tool',
#    'url': 'https://api.github.com/repos/ewgenius/material-color-tool'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/23022274?',
#    'display_login': 'fadeaway1992',
#    'gravatar_id': '',
#    'id': 23022274,
#    'login': 'fadeaway1992',
#    'url': 'https://api.github.com/users/fadeaway1992'},
#   'created_at': '2018-07-29T05:34:09Z',
#   'id': '8033420728',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/2178663?',
#    'gravatar_id': '',
#    'id': 2178663,
#    'login': 'TryGhost',
#    'url': 'https://api.github.com/orgs/TryGhost'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'repo': {'id': 9852918,
#    'name': 'TryGhost/Ghost',
#    'url': 'https://api.github.com/repos/TryGhost/Ghost'},
#   'type': 'WatchEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/1406573?',
#    'display_login': 'chriskelsey',
#    'gravatar_id': '',
#    'id': 1406573,
#    'login': 'chriskelsey',
#    'url': 'https://api.github.com/users/chriskelsey'},
#   'created_at': '2018-07-29T05:34:09Z',
#   'id': '8033420724',
#   'payload': {'before': '4d0f7b63f95da1ad0c945a9890931f7f2c6f9683',
#    'commits': [{'author': {'email': 'chriskelsey.net@gmail.com',
#       'name': 'chriskelsey'},
#      'distinct': True,
#      'message': 'Final project commit',
#      'sha': '3dfffd6f69f7af7cdc507219a7d19c402dd12869',
#      'url': 'https://api.github.com/repos/chriskelsey/liri-node-app/commits/3dfffd6f69f7af7cdc507219a7d19c402dd12869'}],
#    'distinct_size': 1,
#    'head': '3dfffd6f69f7af7cdc507219a7d19c402dd12869',
#    'push_id': 2755391059,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 141928425,
#    'name': 'chriskelsey/liri-node-app',
#    'url': 'https://api.github.com/repos/chriskelsey/liri-node-app'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/26728487?',
#    'display_login': 'jefelewis',
#    'gravatar_id': '',
#    'id': 26728487,
#    'login': 'jefelewis',
#    'url': 'https://api.github.com/users/jefelewis'},
#   'created_at': '2018-07-29T05:34:09Z',
#   'id': '8033420723',
#   'payload': {'before': 'eed8aa0c14e64fcd76155166f87a13222c515cfb',
#    'commits': [{'author': {'email': 'jeffylew77@gmail.com',
#       'name': 'Jeff Lewis'},
#      'distinct': True,
#      'message': '[Dev] Adding gh-pages dependency',
#      'sha': '47c50bf6c074ce08ca9be401da734f3f92560c36',
#      'url': 'https://api.github.com/repos/jefelewis/jefelewis.github.io/commits/47c50bf6c074ce08ca9be401da734f3f92560c36'}],
#    'distinct_size': 1,
#    'head': '47c50bf6c074ce08ca9be401da734f3f92560c36',
#    'push_id': 2755391058,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 140059388,
#    'name': 'jefelewis/jefelewis.github.io',
#    'url': 'https://api.github.com/repos/jefelewis/jefelewis.github.io'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/38429025?',
#    'display_login': 'chuan12',
#    'gravatar_id': '',
#    'id': 38429025,
#    'login': 'chuan12',
#    'url': 'https://api.github.com/users/chuan12'},
#   'created_at': '2018-07-29T05:34:09Z',
#   'id': '8033420722',
#   'payload': {'before': 'a188d1ceaa365788c648414d2fb0aa6b6539d401',
#    'commits': [{'author': {'email': '38429025+chuan12@users.noreply.github.com',
#       'name': 'chuan12'},
#      'distinct': True,
#      'message': 'Update data.js',
#      'sha': '6aee953ebf3ab96caccab7d80242b3a9fd4a0251',
#      'url': 'https://api.github.com/repos/chuan12/shenzhouzd/commits/6aee953ebf3ab96caccab7d80242b3a9fd4a0251'}],
#    'distinct_size': 1,
#    'head': '6aee953ebf3ab96caccab7d80242b3a9fd4a0251',
#    'push_id': 2755391056,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 129750934,
#    'name': 'chuan12/shenzhouzd',
#    'url': 'https://api.github.com/repos/chuan12/shenzhouzd'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/18641678?',
#    'display_login': 'zhangguanzhang',
#    'gravatar_id': '',
#    'id': 18641678,
#    'login': 'zhangguanzhang',
#    'url': 'https://api.github.com/users/zhangguanzhang'},
#   'created_at': '2018-07-29T05:34:09Z',
#   'id': '8033420721',
#   'payload': {'before': '333e630fbdd79c3aa31497da94605b7812712de0',
#    'commits': [{'author': {'email': 'zhangguanzhang@qq.com',
#       'name': 'zhangguanzhang'},
#      'distinct': True,
#      'message': 'Synchronizing completion at 2018-07-29',
#      'sha': 'b84cca87016a695e8fca83c8f9b0ec989eb564f7',
#      'url': 'https://api.github.com/repos/zhangguanzhang/gcr.io/commits/b84cca87016a695e8fca83c8f9b0ec989eb564f7'}],
#    'distinct_size': 1,
#    'head': 'b84cca87016a695e8fca83c8f9b0ec989eb564f7',
#    'push_id': 2755391055,
#    'ref': 'refs/heads/develop',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 139584441,
#    'name': 'zhangguanzhang/gcr.io',
#    'url': 'https://api.github.com/repos/zhangguanzhang/gcr.io'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/7995581?',
#    'display_login': 'antshpra',
#    'gravatar_id': '',
#    'id': 7995581,
#    'login': 'antshpra',
#    'url': 'https://api.github.com/users/antshpra'},
#   'created_at': '2018-07-29T05:34:09Z',
#   'id': '8033420720',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/8576099?',
#    'gravatar_id': '',
#    'id': 8576099,
#    'login': 'Pratilipi',
#    'url': 'https://api.github.com/orgs/Pratilipi'},
#   'payload': {'pusher_type': 'user',
#    'ref': 'release-android',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 21470111,
#    'name': 'Pratilipi/pratilipi',
#    'url': 'https://api.github.com/repos/Pratilipi/pratilipi'},
#   'type': 'DeleteEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/3211677?',
#    'display_login': 'PCanyi',
#    'gravatar_id': '',
#    'id': 3211677,
#    'login': 'PCanyi',
#    'url': 'https://api.github.com/users/PCanyi'},
#   'created_at': '2018-07-29T05:34:09Z',
#   'id': '8033420719',
#   'payload': {'action': 'started'},
#   'public': True,
#   'repo': {'id': 24131321,
#    'name': 'Stonekity/ShopManager',
#    'url': 'https://api.github.com/repos/Stonekity/ShopManager'},
#   'type': 'WatchEvent'}]

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# ### `Response Status Code`

# %% [markdown]
# ## 3 - Raw Response Content
#
# 드문 경우에, 서버로부터 소켓 응답을 받아야 할 때가 있다.
#
# 이때는 `r.raw`를 사용하여, `stream=True` 옵션을 반드시 사용한다.

# %%
r = requests.get('https://api.github.com/events', stream=True)

r.raw

# %%
r.raw.read(10)
# Out:
# b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03'

# %%
# 하지만 이런 경우에는 아래와 같이 코드를 짜서 스트림 내용을 파일에 써야 한다
with open(filename, 'wb') as fd:
    for chunk in r.iter_content(chunk_size=128):
        fd.write(chunk)

# %% [markdown]
# # Custom Headers
#
# 리퀘스트에 HTTP 헤더를 추가하고 싶다면, `headers` 파라미터에 `dict`를 넣어주면 된다.

# %%
url = 'https://api.github.com/some/endpoint'
headers= {'user-agent':'my-app/0.0.1'}

r = requests.get(url, headers=headers)

# %% [markdown]
# # More Complicated POST requests
#
# 일반적으로, HTML과 같이 인코딩된 데이터를 서버에 보내는 경우가 많다.
#
# 이럴 때는 `data` 인자에 딕셔너리를 전달하면 되고, 이 딕셔너리를 자동으로 인코드 된다.

# %%
payload = {'key1':'value1', 'key2':'value2'}

r = requests.post("http://httpbin.org/post", data=payload)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.9.1"
#   },
#   "json": null,
#   "origin": "52.78.180.161",
#   "url": "http://httpbin.org/post"
# }

# %% [markdown]
# # Rest API
#
# REST : * **RE**presentational **S**tate **T**ransfer*
#
#
# 1. Resource Based
#
# REST에서는 행동이 아닌 어떤 '것'인 리소스를 다룬다.
#
# 명사와 동사로 따지면 명사에 속하는 것이다.
#
# 이 리소스는 URI에 의해 구분되는데, 여러개의 URI가 하나의 리소스를 참조할 수 있다.
#
#
# - Things vs. actions
#     REST는 행동이 아닌
# - Nouns vs. verbs
# - Versus SOAP-PRC
# - Identified by URIs
# - Separate from their representation(s)
# representation이 리소스는 아니다. 둘은 별개다
#
#
# 2. Representations
#     - How resources get manipulated
#     - Part of the resource state
#         - Transferred btw client and server
#     - Typically JSON or XML
#     - Example :
#         - Resource : Person (Todd)
#         - Service : Contact Information (GET)
#         - Representation :
#             -name, address, phone number
#             -json or xml format
#
# 3, Uniform Interface
#     - Defines the interface btw client and server
#     - Simplifies and decouples the architecture
#     - Fundamental to RESTful design
#     -
